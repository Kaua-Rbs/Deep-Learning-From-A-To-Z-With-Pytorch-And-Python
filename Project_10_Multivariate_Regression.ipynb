# %% [markdown]
# <a href="https://colab.research.google.com/github/Kaua-Rbs/Deep-Learning-From-A-To-Z-With-Pytorch-And-Python/blob/main/Project_10_Multivariate_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Project 10: Video Games Sales Regression

# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import torch
from torch import nn, optim
import torch.nn.functional as F
import matplotlib.pyplot as plt
import seaborn as sns
torch.__version__
# Out:
# '2.3.0+cu121'

# %% [markdown]
# ## Database

# %%
torch.manual_seed(123)

# %%
base = pd.read_csv('games.csv')

# %%
base.head()
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
#    Critic_Count User_Score  User_Count Developer Rating
# 0          51.0          8       322.0  Nintendo      E
# 1           NaN        NaN         NaN       NaN    NaN
# 2          73.0        8.3       709.0  Nintendo      E
# 3          73.0          8       192.0  Nintendo      E
# 4           NaN        NaN         NaN       NaN    NaN

# %%
base.shape
# Out:
# (16719, 16)

# %%
base = base.drop('Other_Sales', axis = 1)
base = base.drop('Global_Sales', axis = 1)
base = base.drop('Developer', axis = 1)

# %%
base.shape
# Out:
# (16719, 13)

# %%
sns.heatmap(base.isnull());

# %%
base = base.dropna(axis = 0)

# %%
sns.heatmap(base.isnull());

# %%
base.shape
# Out:
# (6825, 13)

# %%
base.loc[base['NA_Sales'] > 1]
# Out:
#                                 Name Platform  Year_of_Release         Genre  \
# 0                         Wii Sports      Wii           2006.0        Sports
# 2                     Mario Kart Wii      Wii           2008.0        Racing
# 3                  Wii Sports Resort      Wii           2009.0        Sports
# 6              New Super Mario Bros.       DS           2006.0      Platform
# 7                           Wii Play      Wii           2006.0          Misc
# ...                              ...      ...              ...           ...
# 1872                NCAA Football 14     X360           2013.0        Sports
# 1877                         NFL 2K1       DC           2000.0        Sports
# 1881                 Madden NFL 2004       XB           2003.0        Sports
# 1889                NCAA Football 13     X360           2012.0        Action
# 1953  Diablo II: Lord of Destruction       PC           2001.0  Role-Playing
#
#             Publisher  NA_Sales  EU_Sales  JP_Sales  Critic_Score  \
# 0            Nintendo     41.36     28.96      3.77          76.0
# 2            Nintendo     15.68     12.76      3.79          82.0
# 3            Nintendo     15.61     10.93      3.28          80.0
# 6            Nintendo     11.28      9.14      6.50          89.0
# 7            Nintendo     13.96      9.18      2.93          58.0
# ...               ...       ...       ...       ...           ...
# 1872  Electronic Arts      1.01      0.00      0.00          77.0
# 1877             Sega      1.02      0.05      0.00          97.0
# 1881  Electronic Arts      1.02      0.02      0.00          92.0
# 1889  Electronic Arts      1.02      0.00      0.00          76.0
# 1953    Vivendi Games      1.03      0.02      0.00          87.0
#
#       Critic_Count User_Score  User_Count Rating
# 0             51.0          8       322.0      E
# 2             73.0        8.3       709.0      E
# 3             73.0          8       192.0      E
# 6             65.0        8.5       431.0      E
# 7             41.0        6.6       129.0      E
# ...            ...        ...         ...    ...
# 1872          18.0        5.8        74.0      E
# 1877          22.0          6        47.0      E
# 1881          27.0        8.3        48.0      E
# 1889          20.0        5.5        65.0      E
# 1953          21.0        9.1       639.0      M
#
# [584 rows x 13 columns]

# %%
base = base.loc[base['NA_Sales'] > 1]

# %%
base.shape
# Out:
# (584, 13)

# %%
base.loc[base['EU_Sales'] > 1]
# Out:
#                            Name Platform  Year_of_Release       Genre  \
# 0                    Wii Sports      Wii           2006.0      Sports
# 2                Mario Kart Wii      Wii           2008.0      Racing
# 3             Wii Sports Resort      Wii           2009.0      Sports
# 6         New Super Mario Bros.       DS           2006.0    Platform
# 7                      Wii Play      Wii           2006.0        Misc
# ..                          ...      ...              ...         ...
# 568              Medal of Honor       PS           1998.0     Shooter
# 573  Tom Clancy's Splinter Cell      PS2           2003.0      Action
# 591      Mario Strikers Charged      Wii           2007.0      Sports
# 610                  Crazy Taxi      PS2           2001.0      Racing
# 636       The Sims: Bustin' Out      PS2           2003.0  Simulation
#
#                  Publisher  NA_Sales  EU_Sales  JP_Sales  Critic_Score  \
# 0                 Nintendo     41.36     28.96      3.77          76.0
# 2                 Nintendo     15.68     12.76      3.79          82.0
# 3                 Nintendo     15.61     10.93      3.28          80.0
# 6                 Nintendo     11.28      9.14      6.50          89.0
# 7                 Nintendo     13.96      9.18      2.93          58.0
# ..                     ...       ...       ...       ...           ...
# 568        Electronic Arts      1.44      1.09      0.00          92.0
# 573                Ubisoft      1.15      1.11      0.00          89.0
# 591               Nintendo      1.05      1.05      0.24          79.0
# 610  Acclaim Entertainment      1.13      1.12      0.06          80.0
# 636        Electronic Arts      1.07      1.19      0.00          81.0
#
#      Critic_Count User_Score  User_Count Rating
# 0            51.0          8       322.0      E
# 2            73.0        8.3       709.0      E
# 3            73.0          8       192.0      E
# 6            65.0        8.5       431.0      E
# 7            41.0        6.6       129.0      E
# ..            ...        ...         ...    ...
# 568          17.0        8.6        80.0      T
# 573          24.0        7.7       102.0      T
# 591          47.0          8       124.0   E10+
# 610          15.0        7.9        46.0      T
# 636          26.0        8.4        42.0      T
#
# [258 rows x 13 columns]

# %%
base = base.loc[base['EU_Sales'] > 1]

# %%
base.shape
# Out:
# (258, 13)

# %%
base['Name'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0                      Wii Sports
# 2                  Mario Kart Wii
# 3               Wii Sports Resort
# 6           New Super Mario Bros.
# 7                        Wii Play
#                   ...
# 568                Medal of Honor
# 573    Tom Clancy's Splinter Cell
# 591        Mario Strikers Charged
# 610                    Crazy Taxi
# 636         The Sims: Bustin' Out
# Name: Name, Length: 258, dtype: object>

# %%
base = base.drop('Name', axis = 1)

# %%
base.shape
# Out:
# (258, 12)

# %%
previsores = base.iloc[:, [0, 1, 2, 3, 7, 8, 9, 10, 11]].values
vendas = base.iloc[:, 4:7].values

# %%
previsores
# Out:
# array([['Wii', 2006.0, 'Sports', ..., '8', 322.0, 'E'],
#        ['Wii', 2008.0, 'Racing', ..., '8.3', 709.0, 'E'],
#        ['Wii', 2009.0, 'Sports', ..., '8', 192.0, 'E'],
#        ...,
#        ['Wii', 2007.0, 'Sports', ..., '8', 124.0, 'E10+'],
#        ['PS2', 2001.0, 'Racing', ..., '7.9', 46.0, 'T'],
#        ['PS2', 2003.0, 'Simulation', ..., '8.4', 42.0, 'T']], dtype=object)

# %%
vendas
# Out:
# array([[4.136e+01, 2.896e+01, 3.770e+00],
#        [1.568e+01, 1.276e+01, 3.790e+00],
#        [1.561e+01, 1.093e+01, 3.280e+00],
#        [1.128e+01, 9.140e+00, 6.500e+00],
#        [1.396e+01, 9.180e+00, 2.930e+00],
#        [1.444e+01, 6.940e+00, 4.700e+00],
#        [9.710e+00, 7.470e+00, 4.130e+00],
#        [8.920e+00, 8.030e+00, 3.600e+00],
#        [1.500e+01, 4.890e+00, 2.400e-01],
#        [9.010e+00, 8.490e+00, 2.530e+00],
#        [7.020e+00, 9.090e+00, 9.800e-01],
#        [4.740e+00, 9.200e+00, 4.160e+00],
#        [9.660e+00, 5.140e+00, 6.000e-02],
#        [8.410e+00, 5.490e+00, 4.700e-01],
#        [3.430e+00, 5.350e+00, 5.320e+00],
#        [6.850e+00, 5.090e+00, 1.870e+00],
#        [9.040e+00, 4.240e+00, 1.300e-01],
#        [9.700e+00, 3.680e+00, 1.100e-01],
#        [4.990e+00, 5.730e+00, 6.500e-01],
#        [8.250e+00, 4.240e+00, 7.000e-02],
#        [8.520e+00, 3.590e+00, 8.000e-02],
#        [5.540e+00, 5.730e+00, 4.900e-01],
#        [6.990e+00, 4.510e+00, 3.000e-01],
#        [6.620e+00, 2.550e+00, 2.660e+00],
#        [5.030e+00, 4.020e+00, 2.690e+00],
#        [5.990e+00, 4.370e+00, 4.800e-01],
#        [3.960e+00, 6.310e+00, 3.800e-01],
#        [2.500e+00, 3.450e+00, 5.330e+00],
#        [7.970e+00, 2.810e+00, 1.300e-01],
#        [6.060e+00, 3.350e+00, 1.200e+00],
#        [6.760e+00, 3.070e+00, 1.400e-01],
#        [4.020e+00, 3.870e+00, 2.540e+00],
#        [4.890e+00, 3.000e+00, 2.140e+00],
#        [2.960e+00, 4.820e+00, 8.100e-01],
#        [4.990e+00, 3.640e+00, 3.800e-01],
#        [4.760e+00, 3.690e+00, 4.400e-01],
#        [6.730e+00, 2.560e+00, 4.000e-02],
#        [5.950e+00, 3.110e+00, 0.000e+00],
#        [3.660e+00, 3.140e+00, 2.470e+00],
#        [7.040e+00, 1.950e+00, 8.000e-02],
#        [3.010e+00, 2.470e+00, 3.280e+00],
#        [6.650e+00, 2.280e+00, 4.000e-02],
#        [3.880e+00, 3.420e+00, 1.690e+00],
#        [5.800e+00, 2.850e+00, 1.000e-02],
#        [4.100e+00, 3.630e+00, 3.800e-01],
#        [5.930e+00, 2.360e+00, 1.300e-01],
#        [2.030e+00, 2.360e+00, 4.390e+00],
#        [4.400e+00, 1.850e+00, 1.980e+00],
#        [5.050e+00, 2.790e+00, 1.000e-01],
#        [1.120e+00, 6.120e+00, 6.000e-02],
#        [6.820e+00, 1.530e+00, 5.000e-02],
#        [1.750e+00, 3.470e+00, 2.490e+00],
#        [3.740e+00, 2.240e+00, 1.580e+00],
#        [1.060e+00, 5.010e+00, 1.300e-01],
#        [2.910e+00, 2.070e+00, 2.730e+00],
#        [2.280e+00, 1.720e+00, 3.630e+00],
#        [2.760e+00, 1.720e+00, 2.690e+00],
#        [2.900e+00, 2.810e+00, 2.400e-01],
#        [2.810e+00, 3.480e+00, 1.400e-01],
#        [3.560e+00, 2.350e+00, 9.800e-01],
#        [4.810e+00, 1.880e+00, 0.000e+00],
#        [4.460e+00, 2.110e+00, 6.000e-02],
#        [3.270e+00, 2.830e+00, 8.000e-02],
#        [3.480e+00, 2.990e+00, 0.000e+00],
#        [2.850e+00, 2.890e+00, 3.500e-01],
#        [2.530e+00, 3.270e+00, 2.400e-01],
#        [3.270e+00, 2.220e+00, 1.400e+00],
#        [3.740e+00, 2.140e+00, 6.000e-01],
#        [3.680e+00, 1.750e+00, 1.420e+00],
#        [3.150e+00, 2.150e+00, 1.280e+00],
#        [4.410e+00, 1.040e+00, 1.390e+00],
#        [2.710e+00, 3.020e+00, 8.000e-02],
#        [2.930e+00, 2.750e+00, 1.700e-01],
#        [4.050e+00, 2.160e+00, 0.000e+00],
#        [4.150e+00, 1.900e+00, 6.000e-02],
#        [2.770e+00, 2.750e+00, 1.900e-01],
#        [3.110e+00, 2.260e+00, 2.800e-01],
#        [3.270e+00, 2.200e+00, 2.100e-01],
#        [1.660e+00, 2.750e+00, 1.600e+00],
#        [2.790e+00, 2.530e+00, 1.700e-01],
#        [2.640e+00, 2.520e+00, 1.600e-01],
#        [3.170e+00, 1.790e+00, 1.030e+00],
#        [4.980e+00, 1.300e+00, 8.000e-02],
#        [2.550e+00, 2.600e+00, 2.500e-01],
#        [2.570e+00, 1.580e+00, 2.060e+00],
#        [3.640e+00, 1.200e+00, 1.490e+00],
#        [4.340e+00, 1.340e+00, 6.000e-02],
#        [3.700e+00, 1.950e+00, 9.000e-02],
#        [4.010e+00, 1.260e+00, 8.700e-01],
#        [3.110e+00, 2.800e+00, 2.000e-02],
#        [4.050e+00, 1.590e+00, 7.000e-02],
#        [3.920e+00, 1.730e+00, 3.000e-02],
#        [3.540e+00, 1.880e+00, 7.000e-02],
#        [2.450e+00, 2.010e+00, 8.700e-01],
#        [3.180e+00, 1.830e+00, 7.800e-01],
#        [2.630e+00, 1.710e+00, 8.300e-01],
#        [2.410e+00, 2.180e+00, 2.800e-01],
#        [2.800e+00, 1.980e+00, 1.700e-01],
#        [1.880e+00, 1.470e+00, 2.020e+00],
#        [2.260e+00, 1.890e+00, 1.360e+00],
#        [2.490e+00, 2.070e+00, 1.600e-01],
#        [3.570e+00, 1.550e+00, 0.000e+00],
#        [3.070e+00, 1.910e+00, 7.000e-02],
#        [2.540e+00, 1.930e+00, 2.100e-01],
#        [3.280e+00, 1.640e+00, 7.000e-02],
#        [2.990e+00, 1.900e+00, 1.000e-01],
#        [3.140e+00, 1.240e+00, 9.100e-01],
#        [2.710e+00, 1.850e+00, 1.100e-01],
#        [2.810e+00, 2.190e+00, 0.000e+00],
#        [2.620e+00, 1.640e+00, 9.900e-01],
#        [2.070e+00, 2.290e+00, 2.400e-01],
#        [2.730e+00, 1.830e+00, 0.000e+00],
#        [1.850e+00, 2.500e+00, 1.900e-01],
#        [1.740e+00, 1.210e+00, 1.870e+00],
#        [3.130e+00, 1.690e+00, 3.000e-02],
#        [1.920e+00, 1.080e+00, 2.110e+00],
#        [3.220e+00, 1.550e+00, 1.000e-02],
#        [3.110e+00, 1.550e+00, 8.000e-02],
#        [2.300e+00, 1.340e+00, 1.270e+00],
#        [1.210e+00, 2.430e+00, 1.030e+00],
#        [1.090e+00, 3.470e+00, 3.000e-02],
#        [2.440e+00, 2.160e+00, 0.000e+00],
#        [1.980e+00, 2.230e+00, 1.300e-01],
#        [3.590e+00, 1.080e+00, 5.000e-02],
#        [1.960e+00, 1.410e+00, 1.080e+00],
#        [1.850e+00, 1.800e+00, 9.500e-01],
#        [2.050e+00, 1.160e+00, 1.110e+00],
#        [1.700e+00, 1.990e+00, 1.600e-01],
#        [3.420e+00, 1.380e+00, 2.000e-02],
#        [3.050e+00, 1.170e+00, 2.900e-01],
#        [2.310e+00, 1.720e+00, 1.200e-01],
#        [2.570e+00, 1.680e+00, 0.000e+00],
#        [1.910e+00, 2.000e+00, 9.000e-02],
#        [2.740e+00, 1.330e+00, 1.200e-01],
#        [2.570e+00, 1.570e+00, 4.400e-01],
#        [2.830e+00, 1.480e+00, 0.000e+00],
#        [2.360e+00, 2.100e+00, 2.000e-02],
#        [2.990e+00, 1.270e+00, 4.000e-02],
#        [3.050e+00, 1.410e+00, 2.000e-02],
#        [1.940e+00, 1.950e+00, 8.000e-02],
#        [2.290e+00, 1.970e+00, 1.300e-01],
#        [1.820e+00, 1.120e+00, 1.320e+00],
#        [2.070e+00, 1.710e+00, 8.000e-02],
#        [3.040e+00, 1.110e+00, 0.000e+00],
#        [1.800e+00, 1.390e+00, 1.110e+00],
#        [2.080e+00, 1.970e+00, 6.000e-02],
#        [2.780e+00, 1.270e+00, 3.000e-02],
#        [2.710e+00, 1.510e+00, 3.000e-02],
#        [1.610e+00, 2.000e+00, 1.500e-01],
#        [2.710e+00, 1.290e+00, 2.000e-02],
#        [1.540e+00, 1.180e+00, 1.460e+00],
#        [2.520e+00, 1.110e+00, 4.600e-01],
#        [2.660e+00, 1.290e+00, 1.000e-02],
#        [2.820e+00, 1.030e+00, 1.300e-01],
#        [2.030e+00, 1.790e+00, 8.000e-02],
#        [2.640e+00, 1.330e+00, 1.000e-02],
#        [1.740e+00, 1.720e+00, 1.400e-01],
#        [2.110e+00, 1.160e+00, 7.300e-01],
#        [2.510e+00, 1.240e+00, 1.100e-01],
#        [3.000e+00, 1.110e+00, 5.000e-02],
#        [2.240e+00, 1.310e+00, 7.000e-02],
#        [1.410e+00, 2.010e+00, 1.000e-01],
#        [2.510e+00, 1.320e+00, 1.000e-02],
#        [2.450e+00, 1.010e+00, 0.000e+00],
#        [1.280e+00, 1.820e+00, 5.700e-01],
#        [2.250e+00, 1.470e+00, 4.000e-02],
#        [2.030e+00, 1.040e+00, 5.800e-01],
#        [2.570e+00, 1.520e+00, 0.000e+00],
#        [1.100e+00, 2.150e+00, 2.100e-01],
#        [2.660e+00, 1.030e+00, 4.000e-02],
#        [2.350e+00, 1.270e+00, 3.000e-02],
#        [2.120e+00, 1.470e+00, 5.000e-02],
#        [1.400e+00, 1.900e+00, 1.100e-01],
#        [1.680e+00, 1.510e+00, 5.100e-01],
#        [1.130e+00, 2.180e+00, 1.000e-01],
#        [1.020e+00, 2.130e+00, 2.300e-01],
#        [1.190e+00, 2.070e+00, 8.000e-02],
#        [1.530e+00, 1.690e+00, 1.000e-01],
#        [2.030e+00, 1.160e+00, 3.700e-01],
#        [2.150e+00, 1.130e+00, 7.000e-02],
#        [2.090e+00, 1.350e+00, 6.000e-02],
#        [2.290e+00, 1.170e+00, 1.000e-02],
#        [1.160e+00, 2.120e+00, 0.000e+00],
#        [1.530e+00, 1.600e+00, 6.000e-02],
#        [2.130e+00, 1.120e+00, 1.000e-01],
#        [1.780e+00, 1.430e+00, 5.000e-02],
#        [1.350e+00, 1.700e+00, 1.500e-01],
#        [1.050e+00, 1.910e+00, 4.100e-01],
#        [2.400e+00, 1.010e+00, 0.000e+00],
#        [2.030e+00, 1.560e+00, 0.000e+00],
#        [1.370e+00, 2.000e+00, 1.400e-01],
#        [1.930e+00, 1.580e+00, 0.000e+00],
#        [1.330e+00, 1.680e+00, 1.300e-01],
#        [2.130e+00, 1.180e+00, 1.000e-02],
#        [1.580e+00, 1.590e+00, 8.000e-02],
#        [1.650e+00, 1.210e+00, 0.000e+00],
#        [2.080e+00, 1.090e+00, 1.500e-01],
#        [1.930e+00, 1.220e+00, 3.000e-02],
#        [2.020e+00, 1.170e+00, 0.000e+00],
#        [1.350e+00, 1.550e+00, 1.700e-01],
#        [2.180e+00, 1.020e+00, 3.000e-02],
#        [1.600e+00, 1.490e+00, 1.000e-01],
#        [1.560e+00, 1.400e+00, 7.000e-02],
#        [1.230e+00, 1.770e+00, 5.000e-02],
#        [1.900e+00, 1.130e+00, 1.000e-01],
#        [1.300e+00, 1.420e+00, 2.700e-01],
#        [2.150e+00, 1.010e+00, 2.000e-02],
#        [2.100e+00, 1.010e+00, 4.000e-02],
#        [2.100e+00, 1.010e+00, 1.000e-02],
#        [1.550e+00, 1.270e+00, 3.300e-01],
#        [1.130e+00, 2.070e+00, 0.000e+00],
#        [1.090e+00, 1.360e+00, 4.900e-01],
#        [1.750e+00, 1.200e+00, 2.000e-02],
#        [1.830e+00, 1.050e+00, 6.000e-02],
#        [1.560e+00, 1.470e+00, 1.900e-01],
#        [2.040e+00, 1.020e+00, 0.000e+00],
#        [1.450e+00, 1.290e+00, 1.200e-01],
#        [1.470e+00, 1.390e+00, 3.000e-02],
#        [1.990e+00, 1.050e+00, 5.000e-02],
#        [1.900e+00, 1.110e+00, 1.000e-02],
#        [1.500e+00, 1.280e+00, 5.000e-02],
#        [1.890e+00, 1.050e+00, 2.000e-02],
#        [1.350e+00, 1.110e+00, 4.600e-01],
#        [1.780e+00, 1.120e+00, 9.000e-02],
#        [1.270e+00, 1.290e+00, 1.200e-01],
#        [1.700e+00, 1.250e+00, 2.000e-02],
#        [1.060e+00, 1.090e+00, 7.600e-01],
#        [1.210e+00, 1.560e+00, 6.000e-02],
#        [1.520e+00, 1.030e+00, 1.000e-01],
#        [1.400e+00, 1.010e+00, 4.600e-01],
#        [1.720e+00, 1.210e+00, 0.000e+00],
#        [1.750e+00, 1.010e+00, 0.000e+00],
#        [1.290e+00, 1.210e+00, 6.000e-02],
#        [1.850e+00, 1.040e+00, 0.000e+00],
#        [1.400e+00, 1.060e+00, 8.000e-02],
#        [1.380e+00, 1.320e+00, 2.000e-02],
#        [1.670e+00, 1.180e+00, 0.000e+00],
#        [1.580e+00, 1.010e+00, 0.000e+00],
#        [1.010e+00, 1.430e+00, 5.000e-02],
#        [1.040e+00, 1.370e+00, 6.000e-02],
#        [1.360e+00, 1.150e+00, 4.000e-02],
#        [1.330e+00, 1.100e+00, 8.000e-02],
#        [1.540e+00, 1.140e+00, 0.000e+00],
#        [1.410e+00, 1.120e+00, 5.000e-02],
#        [1.510e+00, 1.120e+00, 1.000e-02],
#        [1.070e+00, 1.310e+00, 6.000e-02],
#        [1.280e+00, 1.040e+00, 7.000e-02],
#        [1.050e+00, 1.230e+00, 3.000e-02],
#        [1.350e+00, 1.130e+00, 0.000e+00],
#        [1.410e+00, 1.120e+00, 0.000e+00],
#        [1.250e+00, 1.140e+00, 7.000e-02],
#        [1.210e+00, 1.190e+00, 4.000e-02],
#        [1.230e+00, 1.110e+00, 0.000e+00],
#        [1.440e+00, 1.090e+00, 0.000e+00],
#        [1.150e+00, 1.110e+00, 0.000e+00],
#        [1.050e+00, 1.050e+00, 2.400e-01],
#        [1.130e+00, 1.120e+00, 6.000e-02],
#        [1.070e+00, 1.190e+00, 0.000e+00]])

# %%
# Wii 1 0
# PS2 0 1
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
onehotencorder = ColumnTransformer(transformers=[("OneHot", OneHotEncoder(), [0, 2, 3, 8])], remainder='passthrough')
previsores = onehotencorder.fit_transform(previsores).toarray()

# %%
previsores.shape
# Out:
# (258, 61)

# %% [markdown]
# ## Model Structuring

# %%
# 61 -> 32 -> 32 -> 3
class regressor_torch(nn.Module):
    def __init__(self):
        super().__init__()
        self.dense0 = nn.Linear(61, 32)
        self.dense1 = nn.Linear(32, 32)
        self.activation = nn.Sigmoid()
        self.output = nn.Linear(32, 3)

    def forward(self, X):
        X = self.dense0(X)
        X = self.activation(X)
        X = self.dense1(X)
        X = self.activation(X)
        X = self.output(X)
        return X

# %%
regressor = regressor_torch()

# %%
criterion = nn.MSELoss()
optimizer = optim.Adam(regressor.parameters())

# %%
type(previsores)
# Out:
# numpy.ndarray

# %%
previsores = torch.tensor(previsores, dtype=torch.float)
vendas = torch.tensor(vendas, dtype=torch.float)

# %%
type(previsores)
# Out:
# torch.Tensor

# %%
dataset = torch.utils.data.TensorDataset(previsores, vendas)
train_loader = torch.utils.data.DataLoader(dataset, batch_size = 10, shuffle = True)

# %% [markdown]
# ## Model Training

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
device
# Out:
# 'cuda'

# %%
regressor.to(device)
# Out:
# regressor_torch(
#   (dense0): Linear(in_features=61, out_features=32, bias=True)
#   (dense1): Linear(in_features=32, out_features=32, bias=True)
#   (activation): Sigmoid()
#   (output): Linear(in_features=32, out_features=3, bias=True)
# )

# %%
for epoch in range(2000):

    running_loss = 0.
    running_mse_0 = 0.
    running_mse_1 = 0.
    running_mse_2 = 0.

    for i, data in enumerate(train_loader):
        inputs, labels = data
        inputs, labels = inputs.to(device), labels.to(device)

        optimizer.zero_grad()

        outputs = regressor(inputs)

        mse_0 = F.mse_loss(outputs[:,0], labels[:,0]).item()
        mse_1 = F.mse_loss(outputs[:,1], labels[:,1]).item()
        mse_2 = F.mse_loss(outputs[:,2], labels[:,2]).item()

        running_mse_0 += mse_0 * len(inputs)
        running_mse_1 += mse_1 * len(inputs)
        running_mse_2 += mse_2 * len(inputs)

        loss = criterion(outputs, labels)
        loss.backward()

        optimizer.step()

        loss = loss.item()
        running_loss += loss * len(inputs)

        print('\rÉpoca {:4d} - Loop {:3d} de {:3d}: erro_0 {:6.4f} | erro_1 {:6.4f} | erro_2 {:6.4f} - custo {:6.4f}'.format(epoch + 1,
                      i + 1,
                      len(train_loader),
                      mse_0,
                      mse_1,
                      mse_2,
                      loss), end = '\r')

    print('ÉPOCA {:4d} finalizada: erro_0 {:6.4f} | erro_1 {:6.4f} | erro_2 {:6.4f} - custo {:6.4f}         '.format(epoch + 1,
         running_mse_0/len(dataset),
         running_mse_1/len(dataset),
         running_mse_2/len(dataset),
         running_loss/len(dataset)))
# Out:
# ÉPOCA    1 finalizada: erro_0 21.8178 | erro_1 13.7230 | erro_2 1.3285 - custo 12.2898
# ÉPOCA    2 finalizada: erro_0 18.2655 | erro_1 10.4217 | erro_2 1.1840 - custo 9.9571
# ÉPOCA    3 finalizada: erro_0 15.5166 | erro_1 8.2907 | erro_2 1.1737 - custo 8.3270
# ÉPOCA    4 finalizada: erro_0 13.6868 | erro_1 6.9916 | erro_2 1.1744 - custo 7.2843
# ÉPOCA    5 finalizada: erro_0 12.7259 | erro_1 6.3374 | erro_2 1.1725 - custo 6.7453
# ÉPOCA    6 finalizada: erro_0 12.2527 | erro_1 6.0233 | erro_2 1.1762 - custo 6.4841
# ÉPOCA    7 finalizada: erro_0 12.0585 | erro_1 5.9109 | erro_2 1.1721 - custo 6.3805
# ÉPOCA    8 finalizada: erro_0 11.9757 | erro_1 5.8674 | erro_2 1.1703 - custo 6.3378
# ÉPOCA    9 finalizada: erro_0 11.9577 | erro_1 5.8557 | erro_2 1.1777 - custo 6.3304
# ÉPOCA   10 finalizada: erro_0 11.9362 | erro_1 5.8517 | erro_2 1.1753 - custo 6.3211
# ÉPOCA   11 finalizada: erro_0 11.9383 | erro_1 5.8525 | erro_2 1.1742 - custo 6.3217
# ÉPOCA   12 finalizada: erro_0 11.9565 | erro_1 5.8538 | erro_2 1.1649 - custo 6.3250
# ÉPOCA   13 finalizada: erro_0 11.9334 | erro_1 5.8524 | erro_2 1.1705 - custo 6.3188
# ÉPOCA   14 finalizada: erro_0 11.9253 | erro_1 5.8466 | erro_2 1.1641 - custo 6.3120
# ÉPOCA   15 finalizada: erro_0 11.9330 | erro_1 5.8583 | erro_2 1.1662 - custo 6.3192
# ÉPOCA   16 finalizada: erro_0 11.9236 | erro_1 5.8463 | erro_2 1.1656 - custo 6.3119
# ÉPOCA   17 finalizada: erro_0 11.9152 | erro_1 5.8474 | erro_2 1.1684 - custo 6.3104
# ÉPOCA   18 finalizada: erro_0 11.9233 | erro_1 5.8455 | erro_2 1.1673 - custo 6.3120
# ÉPOCA   19 finalizada: erro_0 11.9080 | erro_1 5.8433 | erro_2 1.1689 - custo 6.3067
# ÉPOCA   20 finalizada: erro_0 11.9233 | erro_1 5.8494 | erro_2 1.1647 - custo 6.3125
# ÉPOCA   21 finalizada: erro_0 11.9222 | erro_1 5.8491 | erro_2 1.1674 - custo 6.3129
# ÉPOCA   22 finalizada: erro_0 11.9261 | erro_1 5.8494 | erro_2 1.1626 - custo 6.3127
# ÉPOCA   23 finalizada: erro_0 11.9416 | erro_1 5.8599 | erro_2 1.1633 - custo 6.3216
# ÉPOCA   24 finalizada: erro_0 11.9323 | erro_1 5.8533 | erro_2 1.1634 - custo 6.3163
# ÉPOCA   25 finalizada: erro_0 11.9143 | erro_1 5.8518 | erro_2 1.1636 - custo 6.3099
# ÉPOCA   26 finalizada: erro_0 11.9001 | erro_1 5.8354 | erro_2 1.1604 - custo 6.2986
# ÉPOCA   27 finalizada: erro_0 11.9378 | erro_1 5.8656 | erro_2 1.1631 - custo 6.3222
# ÉPOCA   28 finalizada: erro_0 11.9326 | erro_1 5.8596 | erro_2 1.1583 - custo 6.3168
# ÉPOCA   29 finalizada: erro_0 11.9053 | erro_1 5.8490 | erro_2 1.1600 - custo 6.3048
# ÉPOCA   30 finalizada: erro_0 11.8819 | erro_1 5.8435 | erro_2 1.1623 - custo 6.2959
# ÉPOCA   31 finalizada: erro_0 11.8886 | erro_1 5.8422 | erro_2 1.1564 - custo 6.2957
# ÉPOCA   32 finalizada: erro_0 11.8800 | erro_1 5.8445 | erro_2 1.1575 - custo 6.2940
# ÉPOCA   33 finalizada: erro_0 11.8618 | erro_1 5.8324 | erro_2 1.1553 - custo 6.2832
# ÉPOCA   34 finalizada: erro_0 11.8738 | erro_1 5.8396 | erro_2 1.1557 - custo 6.2897
# ÉPOCA   35 finalizada: erro_0 11.8472 | erro_1 5.8245 | erro_2 1.1562 - custo 6.2760
# ÉPOCA   36 finalizada: erro_0 11.8975 | erro_1 5.8491 | erro_2 1.1538 - custo 6.3002
# ÉPOCA   37 finalizada: erro_0 11.8824 | erro_1 5.8272 | erro_2 1.1547 - custo 6.2881
# ÉPOCA   38 finalizada: erro_0 11.8507 | erro_1 5.8293 | erro_2 1.1593 - custo 6.2798
# ÉPOCA   39 finalizada: erro_0 11.8540 | erro_1 5.8226 | erro_2 1.1612 - custo 6.2793
# ÉPOCA   40 finalizada: erro_0 11.8616 | erro_1 5.8312 | erro_2 1.1534 - custo 6.2821
# ÉPOCA   41 finalizada: erro_0 11.8566 | erro_1 5.8242 | erro_2 1.1563 - custo 6.2791
# ÉPOCA   42 finalizada: erro_0 11.8254 | erro_1 5.8162 | erro_2 1.1548 - custo 6.2655
# ÉPOCA   43 finalizada: erro_0 11.8826 | erro_1 5.8332 | erro_2 1.1536 - custo 6.2898
# ÉPOCA   44 finalizada: erro_0 11.8332 | erro_1 5.8230 | erro_2 1.1515 - custo 6.2693
# ÉPOCA   45 finalizada: erro_0 11.8414 | erro_1 5.8278 | erro_2 1.1449 - custo 6.2714
# ÉPOCA   46 finalizada: erro_0 11.8578 | erro_1 5.8366 | erro_2 1.1421 - custo 6.2788
# ÉPOCA   47 finalizada: erro_0 11.8644 | erro_1 5.8402 | erro_2 1.1501 - custo 6.2849
# ÉPOCA   48 finalizada: erro_0 11.8639 | erro_1 5.8490 | erro_2 1.1406 - custo 6.2845
# ÉPOCA   49 finalizada: erro_0 11.7932 | erro_1 5.8153 | erro_2 1.1446 - custo 6.2510
# ÉPOCA   50 finalizada: erro_0 11.8762 | erro_1 5.8426 | erro_2 1.1456 - custo 6.2881
# ÉPOCA   51 finalizada: erro_0 11.8574 | erro_1 5.8313 | erro_2 1.1426 - custo 6.2771
# ÉPOCA   52 finalizada: erro_0 11.7779 | erro_1 5.8090 | erro_2 1.1371 - custo 6.2413
# ÉPOCA   53 finalizada: erro_0 11.7950 | erro_1 5.8159 | erro_2 1.1374 - custo 6.2494
# ÉPOCA   54 finalizada: erro_0 11.7766 | erro_1 5.8161 | erro_2 1.1492 - custo 6.2473
# ÉPOCA   55 finalizada: erro_0 11.7965 | erro_1 5.8101 | erro_2 1.1373 - custo 6.2480
# ÉPOCA   56 finalizada: erro_0 11.7665 | erro_1 5.8112 | erro_2 1.1367 - custo 6.2381
# ÉPOCA   57 finalizada: erro_0 11.8628 | erro_1 5.8481 | erro_2 1.1382 - custo 6.2831
# ÉPOCA   58 finalizada: erro_0 11.8269 | erro_1 5.8301 | erro_2 1.1389 - custo 6.2653
# ÉPOCA   59 finalizada: erro_0 11.8443 | erro_1 5.8401 | erro_2 1.1398 - custo 6.2748
# ÉPOCA   60 finalizada: erro_0 11.7924 | erro_1 5.8122 | erro_2 1.1397 - custo 6.2481
# ÉPOCA   61 finalizada: erro_0 11.7521 | erro_1 5.7912 | erro_2 1.1339 - custo 6.2257
# ÉPOCA   62 finalizada: erro_0 11.7576 | erro_1 5.7864 | erro_2 1.1314 - custo 6.2251
# ÉPOCA   63 finalizada: erro_0 11.7783 | erro_1 5.7932 | erro_2 1.1316 - custo 6.2344
# ÉPOCA   64 finalizada: erro_0 11.7348 | erro_1 5.7879 | erro_2 1.1301 - custo 6.2176
# ÉPOCA   65 finalizada: erro_0 11.7931 | erro_1 5.8076 | erro_2 1.1330 - custo 6.2446
# ÉPOCA   66 finalizada: erro_0 11.7693 | erro_1 5.7947 | erro_2 1.1359 - custo 6.2333
# ÉPOCA   67 finalizada: erro_0 11.8290 | erro_1 5.8269 | erro_2 1.1359 - custo 6.2639
# ÉPOCA   68 finalizada: erro_0 11.7720 | erro_1 5.8066 | erro_2 1.1258 - custo 6.2348
# ÉPOCA   69 finalizada: erro_0 11.7296 | erro_1 5.7901 | erro_2 1.1280 - custo 6.2159
# ÉPOCA   70 finalizada: erro_0 11.7334 | erro_1 5.7930 | erro_2 1.1290 - custo 6.2184
# ÉPOCA   71 finalizada: erro_0 11.7272 | erro_1 5.7840 | erro_2 1.1217 - custo 6.2110
# ÉPOCA   72 finalizada: erro_0 11.7580 | erro_1 5.7966 | erro_2 1.1256 - custo 6.2267
# ÉPOCA   73 finalizada: erro_0 11.7467 | erro_1 5.7934 | erro_2 1.1255 - custo 6.2219
# ÉPOCA   74 finalizada: erro_0 11.7108 | erro_1 5.7879 | erro_2 1.1208 - custo 6.2065
# ÉPOCA   75 finalizada: erro_0 11.7533 | erro_1 5.7827 | erro_2 1.1230 - custo 6.2197
# ÉPOCA   76 finalizada: erro_0 11.8418 | erro_1 5.8188 | erro_2 1.1403 - custo 6.2670
# ÉPOCA   77 finalizada: erro_0 11.7864 | erro_1 5.8027 | erro_2 1.1269 - custo 6.2387
# ÉPOCA   78 finalizada: erro_0 11.6783 | erro_1 5.7617 | erro_2 1.1161 - custo 6.1854
# ÉPOCA   79 finalizada: erro_0 11.7126 | erro_1 5.7841 | erro_2 1.1214 - custo 6.2060
# ÉPOCA   80 finalizada: erro_0 11.8199 | erro_1 5.8070 | erro_2 1.1118 - custo 6.2463
# ÉPOCA   81 finalizada: erro_0 11.7308 | erro_1 5.7818 | erro_2 1.1103 - custo 6.2076
# ÉPOCA   82 finalizada: erro_0 11.6975 | erro_1 5.7739 | erro_2 1.1114 - custo 6.1943
# ÉPOCA   83 finalizada: erro_0 11.6712 | erro_1 5.7658 | erro_2 1.1088 - custo 6.1819
# ÉPOCA   84 finalizada: erro_0 11.7205 | erro_1 5.7763 | erro_2 1.1076 - custo 6.2015
# ÉPOCA   85 finalizada: erro_0 11.7470 | erro_1 5.7709 | erro_2 1.1079 - custo 6.2086
# ÉPOCA   86 finalizada: erro_0 11.6985 | erro_1 5.7873 | erro_2 1.1088 - custo 6.1982
# ÉPOCA   87 finalizada: erro_0 11.6794 | erro_1 5.7655 | erro_2 1.0938 - custo 6.1795
# ÉPOCA   88 finalizada: erro_0 11.7872 | erro_1 5.7911 | erro_2 1.1092 - custo 6.2292
# ÉPOCA   89 finalizada: erro_0 11.7057 | erro_1 5.7709 | erro_2 1.1006 - custo 6.1924
# ÉPOCA   90 finalizada: erro_0 11.6618 | erro_1 5.7544 | erro_2 1.0856 - custo 6.1672
# ÉPOCA   91 finalizada: erro_0 11.6613 | erro_1 5.7558 | erro_2 1.0930 - custo 6.1700
# ÉPOCA   92 finalizada: erro_0 11.7145 | erro_1 5.7672 | erro_2 1.0910 - custo 6.1909
# ÉPOCA   93 finalizada: erro_0 11.7699 | erro_1 5.7761 | erro_2 1.0939 - custo 6.2133
# ÉPOCA   94 finalizada: erro_0 11.7015 | erro_1 5.7471 | erro_2 1.0893 - custo 6.1793
# ÉPOCA   95 finalizada: erro_0 11.6512 | erro_1 5.7490 | erro_2 1.0852 - custo 6.1618
# ÉPOCA   96 finalizada: erro_0 11.6697 | erro_1 5.7420 | erro_2 1.0936 - custo 6.1684
# ÉPOCA   97 finalizada: erro_0 11.6493 | erro_1 5.7570 | erro_2 1.1025 - custo 6.1696
# ÉPOCA   98 finalizada: erro_0 11.7203 | erro_1 5.7734 | erro_2 1.0951 - custo 6.1963
# ÉPOCA   99 finalizada: erro_0 11.7241 | erro_1 5.7855 | erro_2 1.0965 - custo 6.2021
# ÉPOCA  100 finalizada: erro_0 11.6491 | erro_1 5.7433 | erro_2 1.0921 - custo 6.1615
# ÉPOCA  101 finalizada: erro_0 11.6886 | erro_1 5.7612 | erro_2 1.0930 - custo 6.1809
# ÉPOCA  102 finalizada: erro_0 11.6588 | erro_1 5.7639 | erro_2 1.0871 - custo 6.1699
# ÉPOCA  103 finalizada: erro_0 11.7806 | erro_1 5.7700 | erro_2 1.1016 - custo 6.2174
# ÉPOCA  104 finalizada: erro_0 11.6865 | erro_1 5.7460 | erro_2 1.0913 - custo 6.1746
# ÉPOCA  105 finalizada: erro_0 11.6595 | erro_1 5.7362 | erro_2 1.0759 - custo 6.1572
# ÉPOCA  106 finalizada: erro_0 11.7027 | erro_1 5.7669 | erro_2 1.0857 - custo 6.1851
# ÉPOCA  107 finalizada: erro_0 11.6495 | erro_1 5.7301 | erro_2 1.0719 - custo 6.1505
# ÉPOCA  108 finalizada: erro_0 11.7236 | erro_1 5.7503 | erro_2 1.0834 - custo 6.1857
# ÉPOCA  109 finalizada: erro_0 11.7083 | erro_1 5.7434 | erro_2 1.0882 - custo 6.1800
# ÉPOCA  110 finalizada: erro_0 11.7088 | erro_1 5.7355 | erro_2 1.0838 - custo 6.1761
# ÉPOCA  111 finalizada: erro_0 11.7040 | erro_1 5.7520 | erro_2 1.0997 - custo 6.1852
# ÉPOCA  112 finalizada: erro_0 11.6052 | erro_1 5.7184 | erro_2 1.0801 - custo 6.1346
# ÉPOCA  113 finalizada: erro_0 11.5871 | erro_1 5.7059 | erro_2 1.0906 - custo 6.1279
# ÉPOCA  114 finalizada: erro_0 11.6251 | erro_1 5.7221 | erro_2 1.0817 - custo 6.1430
# ÉPOCA  115 finalizada: erro_0 11.6220 | erro_1 5.7126 | erro_2 1.0886 - custo 6.1411
# ÉPOCA  116 finalizada: erro_0 11.6636 | erro_1 5.7289 | erro_2 1.0751 - custo 6.1559
# ÉPOCA  117 finalizada: erro_0 11.5927 | erro_1 5.7132 | erro_2 1.0802 - custo 6.1287
# ÉPOCA  118 finalizada: erro_0 11.6334 | erro_1 5.7142 | erro_2 1.0739 - custo 6.1405
# ÉPOCA  119 finalizada: erro_0 11.5984 | erro_1 5.7119 | erro_2 1.0753 - custo 6.1286
# ÉPOCA  120 finalizada: erro_0 11.5233 | erro_1 5.6772 | erro_2 1.0577 - custo 6.0861
# ÉPOCA  121 finalizada: erro_0 11.5918 | erro_1 5.6965 | erro_2 1.0656 - custo 6.1180
# ÉPOCA  122 finalizada: erro_0 11.6178 | erro_1 5.7156 | erro_2 1.0912 - custo 6.1415
# ÉPOCA  123 finalizada: erro_0 11.7037 | erro_1 5.7474 | erro_2 1.0886 - custo 6.1799
# ÉPOCA  124 finalizada: erro_0 11.5899 | erro_1 5.7038 | erro_2 1.0644 - custo 6.1194
# ÉPOCA  125 finalizada: erro_0 11.5785 | erro_1 5.7014 | erro_2 1.0761 - custo 6.1187
# ÉPOCA  126 finalizada: erro_0 11.5747 | erro_1 5.7108 | erro_2 1.0932 - custo 6.1262
# ÉPOCA  127 finalizada: erro_0 11.8317 | erro_1 5.8170 | erro_2 1.0784 - custo 6.2424
# ÉPOCA  128 finalizada: erro_0 11.7420 | erro_1 5.8207 | erro_2 1.0906 - custo 6.2178
# ÉPOCA  129 finalizada: erro_0 11.7034 | erro_1 5.7847 | erro_2 1.0821 - custo 6.1901
# ÉPOCA  130 finalizada: erro_0 11.7525 | erro_1 5.7702 | erro_2 1.0934 - custo 6.2054
# ÉPOCA  131 finalizada: erro_0 11.6320 | erro_1 5.7319 | erro_2 1.0745 - custo 6.1461
# ÉPOCA  132 finalizada: erro_0 11.7039 | erro_1 5.7671 | erro_2 1.0906 - custo 6.1872
# ÉPOCA  133 finalizada: erro_0 11.6880 | erro_1 5.7526 | erro_2 1.0774 - custo 6.1727
# ÉPOCA  134 finalizada: erro_0 11.6568 | erro_1 5.7635 | erro_2 1.0841 - custo 6.1681
# ÉPOCA  135 finalizada: erro_0 11.6915 | erro_1 5.7626 | erro_2 1.0634 - custo 6.1725
# ÉPOCA  136 finalizada: erro_0 11.6582 | erro_1 5.7660 | erro_2 1.0645 - custo 6.1629
# ÉPOCA  137 finalizada: erro_0 11.7906 | erro_1 5.7920 | erro_2 1.0887 - custo 6.2238
# ÉPOCA  138 finalizada: erro_0 11.8053 | erro_1 5.7973 | erro_2 1.1158 - custo 6.2395
# ÉPOCA  139 finalizada: erro_0 11.6659 | erro_1 5.7715 | erro_2 1.1121 - custo 6.1832
# ÉPOCA  140 finalizada: erro_0 11.6770 | erro_1 5.7781 | erro_2 1.1031 - custo 6.1861
# ÉPOCA  141 finalizada: erro_0 11.7144 | erro_1 5.7752 | erro_2 1.0612 - custo 6.1836
# ÉPOCA  142 finalizada: erro_0 11.6897 | erro_1 5.7632 | erro_2 1.0969 - custo 6.1833
# ÉPOCA  143 finalizada: erro_0 11.6732 | erro_1 5.7546 | erro_2 1.0858 - custo 6.1712
# ÉPOCA  144 finalizada: erro_0 11.6771 | erro_1 5.7559 | erro_2 1.0786 - custo 6.1705
# ÉPOCA  145 finalizada: erro_0 11.6567 | erro_1 5.7448 | erro_2 1.0850 - custo 6.1621
# ÉPOCA  146 finalizada: erro_0 11.6472 | erro_1 5.7345 | erro_2 1.0523 - custo 6.1447
# ÉPOCA  147 finalizada: erro_0 11.7548 | erro_1 5.7669 | erro_2 1.1004 - custo 6.2074
# ÉPOCA  148 finalizada: erro_0 11.7070 | erro_1 5.7424 | erro_2 1.0873 - custo 6.1789
# ÉPOCA  149 finalizada: erro_0 11.8314 | erro_1 5.7779 | erro_2 1.0866 - custo 6.2320
# ÉPOCA  150 finalizada: erro_0 11.7914 | erro_1 5.7931 | erro_2 1.0995 - custo 6.2280
# ÉPOCA  151 finalizada: erro_0 11.6402 | erro_1 5.7364 | erro_2 1.0752 - custo 6.1506
# ÉPOCA  152 finalizada: erro_0 11.6057 | erro_1 5.7111 | erro_2 1.0516 - custo 6.1228
# ÉPOCA  153 finalizada: erro_0 11.6625 | erro_1 5.7383 | erro_2 1.0604 - custo 6.1537
# ÉPOCA  154 finalizada: erro_0 11.7521 | erro_1 5.7640 | erro_2 1.0987 - custo 6.2049
# ÉPOCA  155 finalizada: erro_0 11.8157 | erro_1 5.7967 | erro_2 1.1077 - custo 6.2400
# ÉPOCA  156 finalizada: erro_0 11.6594 | erro_1 5.7402 | erro_2 1.0747 - custo 6.1581
# ÉPOCA  157 finalizada: erro_0 11.6534 | erro_1 5.7237 | erro_2 1.0826 - custo 6.1532
# ÉPOCA  158 finalizada: erro_0 11.6961 | erro_1 5.7729 | erro_2 1.1095 - custo 6.1928
# ÉPOCA  159 finalizada: erro_0 11.7057 | erro_1 5.7585 | erro_2 1.1128 - custo 6.1923
# ÉPOCA  160 finalizada: erro_0 11.7287 | erro_1 5.7579 | erro_2 1.1064 - custo 6.1977
# ÉPOCA  161 finalizada: erro_0 11.6851 | erro_1 5.7447 | erro_2 1.1064 - custo 6.1787
# ÉPOCA  162 finalizada: erro_0 11.7031 | erro_1 5.7454 | erro_2 1.1094 - custo 6.1860
# ÉPOCA  163 finalizada: erro_0 11.6770 | erro_1 5.7415 | erro_2 1.1123 - custo 6.1769
# ÉPOCA  164 finalizada: erro_0 11.7182 | erro_1 5.7589 | erro_2 1.0866 - custo 6.1879
# ÉPOCA  165 finalizada: erro_0 11.5944 | erro_1 5.7221 | erro_2 1.0782 - custo 6.1316
# ÉPOCA  166 finalizada: erro_0 11.7224 | erro_1 5.7649 | erro_2 1.0751 - custo 6.1875
# ÉPOCA  167 finalizada: erro_0 11.7218 | erro_1 5.7545 | erro_2 1.0870 - custo 6.1878
# ÉPOCA  168 finalizada: erro_0 11.6729 | erro_1 5.7286 | erro_2 1.0724 - custo 6.1580
# ÉPOCA  169 finalizada: erro_0 11.5943 | erro_1 5.7119 | erro_2 1.0852 - custo 6.1305
# ÉPOCA  170 finalizada: erro_0 11.6062 | erro_1 5.7099 | erro_2 1.0715 - custo 6.1292
# ÉPOCA  171 finalizada: erro_0 11.6028 | erro_1 5.7249 | erro_2 1.0590 - custo 6.1289
# ÉPOCA  172 finalizada: erro_0 11.5817 | erro_1 5.7125 | erro_2 1.0723 - custo 6.1222
# ÉPOCA  173 finalizada: erro_0 11.5358 | erro_1 5.7020 | erro_2 1.0515 - custo 6.0964
# ÉPOCA  174 finalizada: erro_0 11.6241 | erro_1 5.7175 | erro_2 1.0566 - custo 6.1327
# ÉPOCA  175 finalizada: erro_0 11.9494 | erro_1 5.8515 | erro_2 1.1067 - custo 6.3025
# ÉPOCA  176 finalizada: erro_0 11.5892 | erro_1 5.6783 | erro_2 1.0779 - custo 6.1151
# ÉPOCA  177 finalizada: erro_0 11.6020 | erro_1 5.6958 | erro_2 1.0553 - custo 6.1177
# ÉPOCA  178 finalizada: erro_0 11.6521 | erro_1 5.7330 | erro_2 1.0579 - custo 6.1476
# ÉPOCA  179 finalizada: erro_0 11.5618 | erro_1 5.6972 | erro_2 1.0485 - custo 6.1025
# ÉPOCA  180 finalizada: erro_0 11.5701 | erro_1 5.7213 | erro_2 1.0718 - custo 6.1211
# ÉPOCA  181 finalizada: erro_0 11.5535 | erro_1 5.7135 | erro_2 1.0561 - custo 6.1077
# ÉPOCA  182 finalizada: erro_0 11.5423 | erro_1 5.6974 | erro_2 1.0641 - custo 6.1013
# ÉPOCA  183 finalizada: erro_0 11.5897 | erro_1 5.7094 | erro_2 1.0639 - custo 6.1210
# ÉPOCA  184 finalizada: erro_0 11.5754 | erro_1 5.6928 | erro_2 1.0486 - custo 6.1056
# ÉPOCA  185 finalizada: erro_0 11.5745 | erro_1 5.7056 | erro_2 1.0779 - custo 6.1193
# ÉPOCA  186 finalizada: erro_0 11.5600 | erro_1 5.7187 | erro_2 1.0641 - custo 6.1143
# ÉPOCA  187 finalizada: erro_0 11.6703 | erro_1 5.7417 | erro_2 1.0902 - custo 6.1674
# ÉPOCA  188 finalizada: erro_0 11.6507 | erro_1 5.7372 | erro_2 1.0809 - custo 6.1563
# ÉPOCA  189 finalizada: erro_0 11.6052 | erro_1 5.7105 | erro_2 1.0835 - custo 6.1331
# ÉPOCA  190 finalizada: erro_0 11.5904 | erro_1 5.7061 | erro_2 1.0694 - custo 6.1219
# ÉPOCA  191 finalizada: erro_0 11.6637 | erro_1 5.7433 | erro_2 1.0760 - custo 6.1610
# ÉPOCA  192 finalizada: erro_0 11.6304 | erro_1 5.7554 | erro_2 1.1037 - custo 6.1632
# ÉPOCA  193 finalizada: erro_0 11.6954 | erro_1 5.7806 | erro_2 1.1001 - custo 6.1920
# ÉPOCA  194 finalizada: erro_0 11.5535 | erro_1 5.6873 | erro_2 1.0426 - custo 6.0945
# ÉPOCA  195 finalizada: erro_0 11.5535 | erro_1 5.7040 | erro_2 1.0811 - custo 6.1129
# ÉPOCA  196 finalizada: erro_0 11.5478 | erro_1 5.7002 | erro_2 1.0755 - custo 6.1079
# ÉPOCA  197 finalizada: erro_0 11.5763 | erro_1 5.6856 | erro_2 1.0470 - custo 6.1030
# ÉPOCA  198 finalizada: erro_0 11.5564 | erro_1 5.7077 | erro_2 1.0736 - custo 6.1125
# ÉPOCA  199 finalizada: erro_0 11.5255 | erro_1 5.7042 | erro_2 1.0771 - custo 6.1023
# ÉPOCA  200 finalizada: erro_0 11.5196 | erro_1 5.6955 | erro_2 1.0720 - custo 6.0957
# ÉPOCA  201 finalizada: erro_0 11.5709 | erro_1 5.7001 | erro_2 1.0779 - custo 6.1163
# ÉPOCA  202 finalizada: erro_0 11.5590 | erro_1 5.7136 | erro_2 1.0725 - custo 6.1151
# ÉPOCA  203 finalizada: erro_0 11.5110 | erro_1 5.6886 | erro_2 1.0614 - custo 6.0870
# ÉPOCA  204 finalizada: erro_0 11.6042 | erro_1 5.7215 | erro_2 1.0737 - custo 6.1331
# ÉPOCA  205 finalizada: erro_0 11.5940 | erro_1 5.6880 | erro_2 1.0535 - custo 6.1119
# ÉPOCA  206 finalizada: erro_0 11.5972 | erro_1 5.6916 | erro_2 1.0824 - custo 6.1238
# ÉPOCA  207 finalizada: erro_0 11.5894 | erro_1 5.6998 | erro_2 1.0640 - custo 6.1178
# ÉPOCA  208 finalizada: erro_0 11.6312 | erro_1 5.7159 | erro_2 1.0775 - custo 6.1416
# ÉPOCA  209 finalizada: erro_0 11.5821 | erro_1 5.6871 | erro_2 1.0693 - custo 6.1128
# ÉPOCA  210 finalizada: erro_0 11.5831 | erro_1 5.6912 | erro_2 1.0634 - custo 6.1126
# ÉPOCA  211 finalizada: erro_0 11.5739 | erro_1 5.6889 | erro_2 1.0651 - custo 6.1093
# ÉPOCA  212 finalizada: erro_0 11.6024 | erro_1 5.6911 | erro_2 1.0730 - custo 6.1222
# ÉPOCA  213 finalizada: erro_0 11.5566 | erro_1 5.6728 | erro_2 1.0371 - custo 6.0889
# ÉPOCA  214 finalizada: erro_0 11.5558 | erro_1 5.6958 | erro_2 1.0642 - custo 6.1053
# ÉPOCA  215 finalizada: erro_0 11.4682 | erro_1 5.6804 | erro_2 1.0611 - custo 6.0699
# ÉPOCA  216 finalizada: erro_0 11.4995 | erro_1 5.6717 | erro_2 1.0552 - custo 6.0755
# ÉPOCA  217 finalizada: erro_0 11.4506 | erro_1 5.6570 | erro_2 1.0488 - custo 6.0522
# ÉPOCA  218 finalizada: erro_0 11.5049 | erro_1 5.6570 | erro_2 1.0486 - custo 6.0702
# ÉPOCA  219 finalizada: erro_0 11.5584 | erro_1 5.6685 | erro_2 1.0712 - custo 6.0994
# ÉPOCA  220 finalizada: erro_0 11.6284 | erro_1 5.7235 | erro_2 1.1242 - custo 6.1587
# ÉPOCA  221 finalizada: erro_0 11.5329 | erro_1 5.6732 | erro_2 1.0469 - custo 6.0843
# ÉPOCA  222 finalizada: erro_0 11.4387 | erro_1 5.6714 | erro_2 1.0485 - custo 6.0529
# ÉPOCA  223 finalizada: erro_0 11.4874 | erro_1 5.6763 | erro_2 1.0583 - custo 6.0740
# ÉPOCA  224 finalizada: erro_0 11.5158 | erro_1 5.6948 | erro_2 1.0636 - custo 6.0914
# ÉPOCA  225 finalizada: erro_0 11.5015 | erro_1 5.6749 | erro_2 1.0474 - custo 6.0746
# ÉPOCA  226 finalizada: erro_0 11.5279 | erro_1 5.6859 | erro_2 1.0689 - custo 6.0943
# ÉPOCA  227 finalizada: erro_0 11.5038 | erro_1 5.6578 | erro_2 1.0631 - custo 6.0749
# ÉPOCA  228 finalizada: erro_0 11.5543 | erro_1 5.6642 | erro_2 1.0912 - custo 6.1033
# ÉPOCA  229 finalizada: erro_0 11.5380 | erro_1 5.6545 | erro_2 1.0834 - custo 6.0920
# ÉPOCA  230 finalizada: erro_0 11.5532 | erro_1 5.6789 | erro_2 1.0510 - custo 6.0943
# ÉPOCA  231 finalizada: erro_0 11.5198 | erro_1 5.6599 | erro_2 1.0285 - custo 6.0694
# ÉPOCA  232 finalizada: erro_0 11.4274 | erro_1 5.6188 | erro_2 1.0395 - custo 6.0286
# ÉPOCA  233 finalizada: erro_0 11.4900 | erro_1 5.6200 | erro_2 1.0636 - custo 6.0579
# ÉPOCA  234 finalizada: erro_0 11.4814 | erro_1 5.6314 | erro_2 1.0718 - custo 6.0615
# ÉPOCA  235 finalizada: erro_0 11.4880 | erro_1 5.6302 | erro_2 1.0594 - custo 6.0592
# ÉPOCA  236 finalizada: erro_0 11.4826 | erro_1 5.6472 | erro_2 1.0644 - custo 6.0647
# ÉPOCA  237 finalizada: erro_0 11.4578 | erro_1 5.6276 | erro_2 1.0493 - custo 6.0449
# ÉPOCA  238 finalizada: erro_0 11.5151 | erro_1 5.7116 | erro_2 1.0755 - custo 6.1007
# ÉPOCA  239 finalizada: erro_0 11.4367 | erro_1 5.6258 | erro_2 1.0309 - custo 6.0311
# ÉPOCA  240 finalizada: erro_0 11.4172 | erro_1 5.6175 | erro_2 1.0079 - custo 6.0142
# ÉPOCA  241 finalizada: erro_0 11.2832 | erro_1 5.5999 | erro_2 1.0249 - custo 5.9694
# ÉPOCA  242 finalizada: erro_0 11.5346 | erro_1 5.6713 | erro_2 1.1023 - custo 6.1027
# ÉPOCA  243 finalizada: erro_0 11.4700 | erro_1 5.6477 | erro_2 1.0780 - custo 6.0652
# ÉPOCA  244 finalizada: erro_0 11.3977 | erro_1 5.5579 | erro_2 1.0573 - custo 6.0043
# ÉPOCA  245 finalizada: erro_0 11.4547 | erro_1 5.5746 | erro_2 1.0315 - custo 6.0203
# ÉPOCA  246 finalizada: erro_0 11.2076 | erro_1 5.5236 | erro_2 1.0431 - custo 5.9248
# ÉPOCA  247 finalizada: erro_0 11.4903 | erro_1 5.6539 | erro_2 1.0419 - custo 6.0621
# ÉPOCA  248 finalizada: erro_0 11.5929 | erro_1 5.7175 | erro_2 1.0937 - custo 6.1347
# ÉPOCA  249 finalizada: erro_0 11.9274 | erro_1 5.8982 | erro_2 1.1835 - custo 6.3364
# ÉPOCA  250 finalizada: erro_0 11.4808 | erro_1 5.6385 | erro_2 1.0757 - custo 6.0650
# ÉPOCA  251 finalizada: erro_0 11.2862 | erro_1 5.5199 | erro_2 1.0185 - custo 5.9415
# ÉPOCA  252 finalizada: erro_0 11.3082 | erro_1 5.5230 | erro_2 1.0234 - custo 5.9516
# ÉPOCA  253 finalizada: erro_0 11.3715 | erro_1 5.5682 | erro_2 1.0407 - custo 5.9935
# ÉPOCA  254 finalizada: erro_0 11.8769 | erro_1 5.7813 | erro_2 1.1532 - custo 6.2705
# ÉPOCA  255 finalizada: erro_0 11.5611 | erro_1 5.6681 | erro_2 1.1011 - custo 6.1101
# ÉPOCA  256 finalizada: erro_0 11.4022 | erro_1 5.6167 | erro_2 1.0449 - custo 6.0212
# ÉPOCA  257 finalizada: erro_0 11.4394 | erro_1 5.5967 | erro_2 1.0326 - custo 6.0229
# ÉPOCA  258 finalizada: erro_0 11.4579 | erro_1 5.6160 | erro_2 1.0477 - custo 6.0405
# ÉPOCA  259 finalizada: erro_0 11.2992 | erro_1 5.5509 | erro_2 1.0348 - custo 5.9617
# ÉPOCA  260 finalizada: erro_0 11.3382 | erro_1 5.5956 | erro_2 1.0536 - custo 5.9958
# ÉPOCA  261 finalizada: erro_0 11.3079 | erro_1 5.5512 | erro_2 1.0118 - custo 5.9569
# ÉPOCA  262 finalizada: erro_0 11.4205 | erro_1 5.5948 | erro_2 1.0309 - custo 6.0154
# ÉPOCA  263 finalizada: erro_0 11.2355 | erro_1 5.5512 | erro_2 1.0254 - custo 5.9373
# ÉPOCA  264 finalizada: erro_0 11.3414 | erro_1 5.5502 | erro_2 1.0232 - custo 5.9716
# ÉPOCA  265 finalizada: erro_0 11.3912 | erro_1 5.5902 | erro_2 1.0205 - custo 6.0006
# ÉPOCA  266 finalizada: erro_0 11.2747 | erro_1 5.5425 | erro_2 1.0113 - custo 5.9429
# ÉPOCA  267 finalizada: erro_0 11.3536 | erro_1 5.5818 | erro_2 1.0189 - custo 5.9848
# ÉPOCA  268 finalizada: erro_0 11.2449 | erro_1 5.5466 | erro_2 1.0236 - custo 5.9384
# ÉPOCA  269 finalizada: erro_0 11.0651 | erro_1 5.4888 | erro_2 1.0197 - custo 5.8579
# ÉPOCA  270 finalizada: erro_0 12.1738 | erro_1 6.0939 | erro_2 1.2490 - custo 6.5056
# ÉPOCA  271 finalizada: erro_0 12.2590 | erro_1 6.0726 | erro_2 1.2613 - custo 6.5309
# ÉPOCA  272 finalizada: erro_0 11.9613 | erro_1 5.9184 | erro_2 1.2374 - custo 6.3724
# ÉPOCA  273 finalizada: erro_0 12.0769 | erro_1 5.9127 | erro_2 1.2618 - custo 6.4171
# ÉPOCA  274 finalizada: erro_0 12.0749 | erro_1 6.0370 | erro_2 1.2492 - custo 6.4537
# ÉPOCA  275 finalizada: erro_0 12.0918 | erro_1 6.0031 | erro_2 1.1801 - custo 6.4250
# ÉPOCA  276 finalizada: erro_0 11.9811 | erro_1 5.9463 | erro_2 1.1733 - custo 6.3669
# ÉPOCA  277 finalizada: erro_0 12.0129 | erro_1 6.0051 | erro_2 1.2204 - custo 6.4128
# ÉPOCA  278 finalizada: erro_0 11.8677 | erro_1 5.9005 | erro_2 1.1649 - custo 6.3110
# ÉPOCA  279 finalizada: erro_0 11.8444 | erro_1 5.8287 | erro_2 1.1786 - custo 6.2839
# ÉPOCA  280 finalizada: erro_0 11.7788 | erro_1 5.8088 | erro_2 1.1572 - custo 6.2483
# ÉPOCA  281 finalizada: erro_0 11.9625 | erro_1 5.8768 | erro_2 1.1774 - custo 6.3389
# ÉPOCA  282 finalizada: erro_0 11.9551 | erro_1 5.9661 | erro_2 1.1688 - custo 6.3633
# ÉPOCA  283 finalizada: erro_0 11.7099 | erro_1 5.8297 | erro_2 1.1328 - custo 6.2241
# ÉPOCA  284 finalizada: erro_0 12.0164 | erro_1 5.8781 | erro_2 1.1459 - custo 6.3468
# ÉPOCA  285 finalizada: erro_0 11.6831 | erro_1 5.8215 | erro_2 1.1299 - custo 6.2115
# ÉPOCA  286 finalizada: erro_0 11.7449 | erro_1 5.7893 | erro_2 1.1398 - custo 6.2246
# ÉPOCA  287 finalizada: erro_0 11.8420 | erro_1 5.8298 | erro_2 1.1303 - custo 6.2674
# ÉPOCA  288 finalizada: erro_0 11.7259 | erro_1 5.7895 | erro_2 1.1393 - custo 6.2182
# ÉPOCA  289 finalizada: erro_0 11.7137 | erro_1 5.7859 | erro_2 1.1264 - custo 6.2086
# ÉPOCA  290 finalizada: erro_0 11.7849 | erro_1 5.8643 | erro_2 1.1358 - custo 6.2617
# ÉPOCA  291 finalizada: erro_0 11.6797 | erro_1 5.7777 | erro_2 1.1089 - custo 6.1888
# ÉPOCA  292 finalizada: erro_0 11.7615 | erro_1 5.8291 | erro_2 1.1165 - custo 6.2357
# ÉPOCA  293 finalizada: erro_0 11.6995 | erro_1 5.7948 | erro_2 1.1047 - custo 6.1996
# ÉPOCA  294 finalizada: erro_0 11.7123 | erro_1 5.7835 | erro_2 1.1031 - custo 6.1996
# ÉPOCA  295 finalizada: erro_0 11.6660 | erro_1 5.7854 | erro_2 1.1134 - custo 6.1883
# ÉPOCA  296 finalizada: erro_0 11.7180 | erro_1 5.7960 | erro_2 1.1193 - custo 6.2111
# ÉPOCA  297 finalizada: erro_0 11.7238 | erro_1 5.7676 | erro_2 1.0910 - custo 6.1941
# ÉPOCA  298 finalizada: erro_0 11.6939 | erro_1 5.8009 | erro_2 1.1201 - custo 6.2050
# ÉPOCA  299 finalizada: erro_0 11.5985 | erro_1 5.7745 | erro_2 1.1072 - custo 6.1600
# ÉPOCA  300 finalizada: erro_0 11.6644 | erro_1 5.7431 | erro_2 1.1055 - custo 6.1710
# ÉPOCA  301 finalizada: erro_0 11.6526 | erro_1 5.7232 | erro_2 1.1141 - custo 6.1633
# ÉPOCA  302 finalizada: erro_0 11.5842 | erro_1 5.7176 | erro_2 1.1095 - custo 6.1371
# ÉPOCA  303 finalizada: erro_0 11.6673 | erro_1 5.8565 | erro_2 1.1387 - custo 6.2208
# ÉPOCA  304 finalizada: erro_0 11.5958 | erro_1 5.7906 | erro_2 1.1147 - custo 6.1670
# ÉPOCA  305 finalizada: erro_0 11.6863 | erro_1 5.7693 | erro_2 1.1145 - custo 6.1900
# ÉPOCA  306 finalizada: erro_0 11.6484 | erro_1 5.7345 | erro_2 1.1038 - custo 6.1622
# ÉPOCA  307 finalizada: erro_0 11.6973 | erro_1 5.7368 | erro_2 1.1144 - custo 6.1828
# ÉPOCA  308 finalizada: erro_0 11.6952 | erro_1 5.7476 | erro_2 1.1250 - custo 6.1893
# ÉPOCA  309 finalizada: erro_0 11.6548 | erro_1 5.7270 | erro_2 1.1154 - custo 6.1658
# ÉPOCA  310 finalizada: erro_0 11.6235 | erro_1 5.7126 | erro_2 1.1071 - custo 6.1477
# ÉPOCA  311 finalizada: erro_0 11.7373 | erro_1 5.7773 | erro_2 1.1325 - custo 6.2157
# ÉPOCA  312 finalizada: erro_0 11.6302 | erro_1 5.7395 | erro_2 1.1281 - custo 6.1659
# ÉPOCA  313 finalizada: erro_0 11.6308 | erro_1 5.7236 | erro_2 1.1146 - custo 6.1563
# ÉPOCA  314 finalizada: erro_0 11.6534 | erro_1 5.7068 | erro_2 1.1054 - custo 6.1552
# ÉPOCA  315 finalizada: erro_0 11.6452 | erro_1 5.7391 | erro_2 1.0875 - custo 6.1573
# ÉPOCA  316 finalizada: erro_0 11.6570 | erro_1 5.7420 | erro_2 1.1096 - custo 6.1695
# ÉPOCA  317 finalizada: erro_0 11.6989 | erro_1 5.7490 | erro_2 1.0949 - custo 6.1809
# ÉPOCA  318 finalizada: erro_0 11.5838 | erro_1 5.7074 | erro_2 1.0980 - custo 6.1297
# ÉPOCA  319 finalizada: erro_0 11.5812 | erro_1 5.7045 | erro_2 1.0886 - custo 6.1248
# ÉPOCA  320 finalizada: erro_0 11.6344 | erro_1 5.7170 | erro_2 1.0915 - custo 6.1476
# ÉPOCA  321 finalizada: erro_0 11.5829 | erro_1 5.6852 | erro_2 1.0925 - custo 6.1202
# ÉPOCA  322 finalizada: erro_0 11.6267 | erro_1 5.7205 | erro_2 1.0907 - custo 6.1460
# ÉPOCA  323 finalizada: erro_0 11.6098 | erro_1 5.7083 | erro_2 1.0993 - custo 6.1391
# ÉPOCA  324 finalizada: erro_0 11.6492 | erro_1 5.7710 | erro_2 1.0806 - custo 6.1669
# ÉPOCA  325 finalizada: erro_0 11.5502 | erro_1 5.7083 | erro_2 1.0792 - custo 6.1126
# ÉPOCA  326 finalizada: erro_0 11.5883 | erro_1 5.7467 | erro_2 1.0920 - custo 6.1423
# ÉPOCA  327 finalizada: erro_0 11.5846 | erro_1 5.7075 | erro_2 1.0806 - custo 6.1243
# ÉPOCA  328 finalizada: erro_0 11.5895 | erro_1 5.7121 | erro_2 1.0966 - custo 6.1327
# ÉPOCA  329 finalizada: erro_0 11.5711 | erro_1 5.7003 | erro_2 1.0961 - custo 6.1225
# ÉPOCA  330 finalizada: erro_0 11.5778 | erro_1 5.7149 | erro_2 1.0762 - custo 6.1230
# ÉPOCA  331 finalizada: erro_0 11.5444 | erro_1 5.6992 | erro_2 1.0975 - custo 6.1137
# ÉPOCA  332 finalizada: erro_0 11.5515 | erro_1 5.7035 | erro_2 1.0826 - custo 6.1125
# ÉPOCA  333 finalizada: erro_0 11.5609 | erro_1 5.7074 | erro_2 1.0565 - custo 6.1083
# ÉPOCA  334 finalizada: erro_0 11.5787 | erro_1 5.7155 | erro_2 1.0626 - custo 6.1190
# ÉPOCA  335 finalizada: erro_0 11.7833 | erro_1 5.8351 | erro_2 1.1052 - custo 6.2412
# ÉPOCA  336 finalizada: erro_0 11.7152 | erro_1 5.7500 | erro_2 1.0924 - custo 6.1859
# ÉPOCA  337 finalizada: erro_0 11.6214 | erro_1 5.7396 | erro_2 1.0846 - custo 6.1486
# ÉPOCA  338 finalizada: erro_0 11.5668 | erro_1 5.7280 | erro_2 1.0629 - custo 6.1192
# ÉPOCA  339 finalizada: erro_0 11.5175 | erro_1 5.7087 | erro_2 1.0618 - custo 6.0960
# ÉPOCA  340 finalizada: erro_0 11.5908 | erro_1 5.7610 | erro_2 1.0891 - custo 6.1470
# ÉPOCA  341 finalizada: erro_0 11.6066 | erro_1 5.7514 | erro_2 1.0780 - custo 6.1453
# ÉPOCA  342 finalizada: erro_0 11.4546 | erro_1 5.7098 | erro_2 1.0729 - custo 6.0791
# ÉPOCA  343 finalizada: erro_0 11.5403 | erro_1 5.7009 | erro_2 1.0715 - custo 6.1042
# ÉPOCA  344 finalizada: erro_0 11.5418 | erro_1 5.6899 | erro_2 1.0760 - custo 6.1026
# ÉPOCA  345 finalizada: erro_0 11.4700 | erro_1 5.6843 | erro_2 1.0649 - custo 6.0731
# ÉPOCA  346 finalizada: erro_0 11.4559 | erro_1 5.7107 | erro_2 1.0565 - custo 6.0744
# ÉPOCA  347 finalizada: erro_0 11.4875 | erro_1 5.7022 | erro_2 1.0602 - custo 6.0833
# ÉPOCA  348 finalizada: erro_0 11.4971 | erro_1 5.7080 | erro_2 1.0683 - custo 6.0911
# ÉPOCA  349 finalizada: erro_0 11.5747 | erro_1 5.7313 | erro_2 1.0702 - custo 6.1254
# ÉPOCA  350 finalizada: erro_0 11.5384 | erro_1 5.6996 | erro_2 1.0525 - custo 6.0968
# ÉPOCA  351 finalizada: erro_0 11.4609 | erro_1 5.6488 | erro_2 1.0429 - custo 6.0509
# ÉPOCA  352 finalizada: erro_0 11.7506 | erro_1 5.8061 | erro_2 1.0958 - custo 6.2175
# ÉPOCA  353 finalizada: erro_0 11.5638 | erro_1 5.6835 | erro_2 1.0668 - custo 6.1047
# ÉPOCA  354 finalizada: erro_0 11.5838 | erro_1 5.6851 | erro_2 1.0665 - custo 6.1118
# ÉPOCA  355 finalizada: erro_0 11.5103 | erro_1 5.6537 | erro_2 1.0854 - custo 6.0831
# ÉPOCA  356 finalizada: erro_0 11.4494 | erro_1 5.6756 | erro_2 1.0717 - custo 6.0656
# ÉPOCA  357 finalizada: erro_0 11.4171 | erro_1 5.6548 | erro_2 1.0684 - custo 6.0468
# ÉPOCA  358 finalizada: erro_0 11.5014 | erro_1 5.6631 | erro_2 1.0543 - custo 6.0729
# ÉPOCA  359 finalizada: erro_0 11.5600 | erro_1 5.7290 | erro_2 1.0955 - custo 6.1282
# ÉPOCA  360 finalizada: erro_0 11.5707 | erro_1 5.6576 | erro_2 1.0613 - custo 6.0965
# ÉPOCA  361 finalizada: erro_0 11.4732 | erro_1 5.6510 | erro_2 1.0412 - custo 6.0552
# ÉPOCA  362 finalizada: erro_0 11.5512 | erro_1 5.6428 | erro_2 1.0644 - custo 6.0861
# ÉPOCA  363 finalizada: erro_0 11.4972 | erro_1 5.6600 | erro_2 1.0772 - custo 6.0781
# ÉPOCA  364 finalizada: erro_0 11.5428 | erro_1 5.6942 | erro_2 1.0531 - custo 6.0967
# ÉPOCA  365 finalizada: erro_0 11.5735 | erro_1 5.7632 | erro_2 1.0899 - custo 6.1422
# ÉPOCA  366 finalizada: erro_0 11.4909 | erro_1 5.7344 | erro_2 1.0839 - custo 6.1030
# ÉPOCA  367 finalizada: erro_0 11.5555 | erro_1 5.7359 | erro_2 1.0479 - custo 6.1131
# ÉPOCA  368 finalizada: erro_0 11.5695 | erro_1 5.6799 | erro_2 1.0620 - custo 6.1038
# ÉPOCA  369 finalizada: erro_0 11.5451 | erro_1 5.6855 | erro_2 1.0595 - custo 6.0967
# ÉPOCA  370 finalizada: erro_0 11.5348 | erro_1 5.6563 | erro_2 1.0529 - custo 6.0813
# ÉPOCA  371 finalizada: erro_0 11.4455 | erro_1 5.6456 | erro_2 1.0463 - custo 6.0458
# ÉPOCA  372 finalizada: erro_0 11.5156 | erro_1 5.7011 | erro_2 1.0559 - custo 6.0909
# ÉPOCA  373 finalizada: erro_0 11.5028 | erro_1 5.7131 | erro_2 1.0614 - custo 6.0925
# ÉPOCA  374 finalizada: erro_0 11.5133 | erro_1 5.7026 | erro_2 1.0581 - custo 6.0913
# ÉPOCA  375 finalizada: erro_0 11.4924 | erro_1 5.6476 | erro_2 1.0531 - custo 6.0643
# ÉPOCA  376 finalizada: erro_0 11.5130 | erro_1 5.6709 | erro_2 1.0492 - custo 6.0777
# ÉPOCA  377 finalizada: erro_0 11.4564 | erro_1 5.6378 | erro_2 1.0587 - custo 6.0510
# ÉPOCA  378 finalizada: erro_0 11.4467 | erro_1 5.6292 | erro_2 1.0318 - custo 6.0359
# ÉPOCA  379 finalizada: erro_0 11.4834 | erro_1 5.6560 | erro_2 1.0408 - custo 6.0601
# ÉPOCA  380 finalizada: erro_0 11.4761 | erro_1 5.6454 | erro_2 1.0576 - custo 6.0597
# ÉPOCA  381 finalizada: erro_0 11.4041 | erro_1 5.6158 | erro_2 1.0359 - custo 6.0186
# ÉPOCA  382 finalizada: erro_0 11.5663 | erro_1 5.6685 | erro_2 1.0443 - custo 6.0931
# ÉPOCA  383 finalizada: erro_0 11.5442 | erro_1 5.6570 | erro_2 1.0630 - custo 6.0881
# ÉPOCA  384 finalizada: erro_0 11.5803 | erro_1 5.6619 | erro_2 1.0497 - custo 6.0973
# ÉPOCA  385 finalizada: erro_0 11.4485 | erro_1 5.6633 | erro_2 1.0725 - custo 6.0614
# ÉPOCA  386 finalizada: erro_0 11.4341 | erro_1 5.6612 | erro_2 1.0717 - custo 6.0557
# ÉPOCA  387 finalizada: erro_0 11.5037 | erro_1 5.7132 | erro_2 1.0900 - custo 6.1023
# ÉPOCA  388 finalizada: erro_0 11.4351 | erro_1 5.6411 | erro_2 1.0358 - custo 6.0373
# ÉPOCA  389 finalizada: erro_0 11.4945 | erro_1 5.6608 | erro_2 1.0486 - custo 6.0680
# ÉPOCA  390 finalizada: erro_0 11.4738 | erro_1 5.6803 | erro_2 1.0753 - custo 6.0765
# ÉPOCA  391 finalizada: erro_0 11.4540 | erro_1 5.6251 | erro_2 1.0869 - custo 6.0553
# ÉPOCA  392 finalizada: erro_0 11.4069 | erro_1 5.5884 | erro_2 1.0649 - custo 6.0201
# ÉPOCA  393 finalizada: erro_0 11.4572 | erro_1 5.6355 | erro_2 1.1177 - custo 6.0701
# ÉPOCA  394 finalizada: erro_0 11.3698 | erro_1 5.6181 | erro_2 1.1119 - custo 6.0333
# ÉPOCA  395 finalizada: erro_0 11.6723 | erro_1 5.7215 | erro_2 1.1194 - custo 6.1711
# ÉPOCA  396 finalizada: erro_0 11.5768 | erro_1 5.7224 | erro_2 1.1157 - custo 6.1383
# ÉPOCA  397 finalizada: erro_0 11.5531 | erro_1 5.6853 | erro_2 1.0968 - custo 6.1117
# ÉPOCA  398 finalizada: erro_0 11.6542 | erro_1 5.7655 | erro_2 1.1590 - custo 6.1929
# ÉPOCA  399 finalizada: erro_0 11.5542 | erro_1 5.7185 | erro_2 1.0860 - custo 6.1196
# ÉPOCA  400 finalizada: erro_0 11.6105 | erro_1 5.7455 | erro_2 1.0874 - custo 6.1478
# ÉPOCA  401 finalizada: erro_0 11.5538 | erro_1 5.7005 | erro_2 1.0742 - custo 6.1095
# ÉPOCA  402 finalizada: erro_0 11.5115 | erro_1 5.6894 | erro_2 1.0874 - custo 6.0961
# ÉPOCA  403 finalizada: erro_0 11.4696 | erro_1 5.6749 | erro_2 1.0846 - custo 6.0764
# ÉPOCA  404 finalizada: erro_0 11.6038 | erro_1 5.7066 | erro_2 1.0849 - custo 6.1318
# ÉPOCA  405 finalizada: erro_0 11.5663 | erro_1 5.6840 | erro_2 1.0999 - custo 6.1167
# ÉPOCA  406 finalizada: erro_0 11.7857 | erro_1 5.7800 | erro_2 1.1207 - custo 6.2288
# ÉPOCA  407 finalizada: erro_0 11.7042 | erro_1 5.7475 | erro_2 1.1041 - custo 6.1853
# ÉPOCA  408 finalizada: erro_0 11.7692 | erro_1 5.8350 | erro_2 1.1011 - custo 6.2351
# ÉPOCA  409 finalizada: erro_0 11.5381 | erro_1 5.7055 | erro_2 1.0900 - custo 6.1112
# ÉPOCA  410 finalizada: erro_0 11.5758 | erro_1 5.6918 | erro_2 1.1022 - custo 6.1232
# ÉPOCA  411 finalizada: erro_0 11.4902 | erro_1 5.6632 | erro_2 1.1074 - custo 6.0869
# ÉPOCA  412 finalizada: erro_0 11.5391 | erro_1 5.6948 | erro_2 1.0922 - custo 6.1087
# ÉPOCA  413 finalizada: erro_0 11.6053 | erro_1 5.7250 | erro_2 1.1364 - custo 6.1555
# ÉPOCA  414 finalizada: erro_0 11.7094 | erro_1 5.7607 | erro_2 1.1615 - custo 6.2105
# ÉPOCA  415 finalizada: erro_0 11.4949 | erro_1 5.6456 | erro_2 1.0748 - custo 6.0718
# ÉPOCA  416 finalizada: erro_0 11.5535 | erro_1 5.6967 | erro_2 1.1113 - custo 6.1205
# ÉPOCA  417 finalizada: erro_0 11.6709 | erro_1 5.7354 | erro_2 1.0917 - custo 6.1660
# ÉPOCA  418 finalizada: erro_0 11.5736 | erro_1 5.7157 | erro_2 1.0847 - custo 6.1247
# ÉPOCA  419 finalizada: erro_0 11.5771 | erro_1 5.6884 | erro_2 1.0686 - custo 6.1114
# ÉPOCA  420 finalizada: erro_0 11.6144 | erro_1 5.7049 | erro_2 1.0778 - custo 6.1324
# ÉPOCA  421 finalizada: erro_0 11.6580 | erro_1 5.7077 | erro_2 1.0972 - custo 6.1543
# ÉPOCA  422 finalizada: erro_0 11.5246 | erro_1 5.6884 | erro_2 1.1060 - custo 6.1063
# ÉPOCA  423 finalizada: erro_0 11.6593 | erro_1 5.7399 | erro_2 1.0964 - custo 6.1652
# ÉPOCA  424 finalizada: erro_0 11.5943 | erro_1 5.6880 | erro_2 1.0787 - custo 6.1203
# ÉPOCA  425 finalizada: erro_0 11.4961 | erro_1 5.6495 | erro_2 1.0737 - custo 6.0731
# ÉPOCA  426 finalizada: erro_0 11.5851 | erro_1 5.7304 | erro_2 1.1277 - custo 6.1477
# ÉPOCA  427 finalizada: erro_0 11.5543 | erro_1 5.6849 | erro_2 1.0921 - custo 6.1104
# ÉPOCA  428 finalizada: erro_0 11.6651 | erro_1 5.7020 | erro_2 1.1217 - custo 6.1629
# ÉPOCA  429 finalizada: erro_0 11.5818 | erro_1 5.7438 | erro_2 1.1391 - custo 6.1549
# ÉPOCA  430 finalizada: erro_0 11.6484 | erro_1 5.6910 | erro_2 1.1024 - custo 6.1473
# ÉPOCA  431 finalizada: erro_0 11.5442 | erro_1 5.6554 | erro_2 1.1019 - custo 6.1005
# ÉPOCA  432 finalizada: erro_0 11.6050 | erro_1 5.6897 | erro_2 1.1159 - custo 6.1369
# ÉPOCA  433 finalizada: erro_0 11.5862 | erro_1 5.6942 | erro_2 1.0974 - custo 6.1259
# ÉPOCA  434 finalizada: erro_0 11.5384 | erro_1 5.6349 | erro_2 1.1047 - custo 6.0927
# ÉPOCA  435 finalizada: erro_0 11.5410 | erro_1 5.6379 | erro_2 1.0940 - custo 6.0910
# ÉPOCA  436 finalizada: erro_0 11.5265 | erro_1 5.6425 | erro_2 1.0980 - custo 6.0890
# ÉPOCA  437 finalizada: erro_0 11.5461 | erro_1 5.6353 | erro_2 1.0910 - custo 6.0908
# ÉPOCA  438 finalizada: erro_0 11.5269 | erro_1 5.6418 | erro_2 1.0975 - custo 6.0887
# ÉPOCA  439 finalizada: erro_0 11.5372 | erro_1 5.6389 | erro_2 1.0974 - custo 6.0912
# ÉPOCA  440 finalizada: erro_0 11.5334 | erro_1 5.6366 | erro_2 1.0931 - custo 6.0877
# ÉPOCA  441 finalizada: erro_0 11.6019 | erro_1 5.6949 | erro_2 1.0988 - custo 6.1318
# ÉPOCA  442 finalizada: erro_0 11.5129 | erro_1 5.6356 | erro_2 1.0934 - custo 6.0806
# ÉPOCA  443 finalizada: erro_0 11.5111 | erro_1 5.6131 | erro_2 1.0884 - custo 6.0708
# ÉPOCA  444 finalizada: erro_0 11.5347 | erro_1 5.6493 | erro_2 1.0935 - custo 6.0925
# ÉPOCA  445 finalizada: erro_0 11.5111 | erro_1 5.6320 | erro_2 1.0922 - custo 6.0784
# ÉPOCA  446 finalizada: erro_0 11.4952 | erro_1 5.6338 | erro_2 1.0901 - custo 6.0730
# ÉPOCA  447 finalizada: erro_0 11.6383 | erro_1 5.7101 | erro_2 1.0892 - custo 6.1459
# ÉPOCA  448 finalizada: erro_0 11.4579 | erro_1 5.6799 | erro_2 1.0922 - custo 6.0767
# ÉPOCA  449 finalizada: erro_0 11.5037 | erro_1 5.6585 | erro_2 1.1052 - custo 6.0892
# ÉPOCA  450 finalizada: erro_0 11.5080 | erro_1 5.6837 | erro_2 1.1332 - custo 6.1083
# ÉPOCA  451 finalizada: erro_0 11.4452 | erro_1 5.6492 | erro_2 1.1398 - custo 6.0781
# ÉPOCA  452 finalizada: erro_0 11.7677 | erro_1 5.7437 | erro_2 1.0846 - custo 6.1987
# ÉPOCA  453 finalizada: erro_0 11.4462 | erro_1 5.6077 | erro_2 1.0930 - custo 6.0490
# ÉPOCA  454 finalizada: erro_0 11.5992 | erro_1 5.6313 | erro_2 1.1038 - custo 6.1114
# ÉPOCA  455 finalizada: erro_0 11.5022 | erro_1 5.6564 | erro_2 1.1184 - custo 6.0923
# ÉPOCA  456 finalizada: erro_0 11.4561 | erro_1 5.6324 | erro_2 1.0699 - custo 6.0528
# ÉPOCA  457 finalizada: erro_0 11.4155 | erro_1 5.5908 | erro_2 1.0659 - custo 6.0241
# ÉPOCA  458 finalizada: erro_0 11.5133 | erro_1 5.6486 | erro_2 1.0993 - custo 6.0871
# ÉPOCA  459 finalizada: erro_0 11.5217 | erro_1 5.6337 | erro_2 1.0807 - custo 6.0787
# ÉPOCA  460 finalizada: erro_0 11.4677 | erro_1 5.6442 | erro_2 1.1021 - custo 6.0713
# ÉPOCA  461 finalizada: erro_0 11.4520 | erro_1 5.6322 | erro_2 1.0954 - custo 6.0599
# ÉPOCA  462 finalizada: erro_0 11.4401 | erro_1 5.6179 | erro_2 1.0884 - custo 6.0488
# ÉPOCA  463 finalizada: erro_0 11.4545 | erro_1 5.6313 | erro_2 1.1030 - custo 6.0629
# ÉPOCA  464 finalizada: erro_0 11.4978 | erro_1 5.6378 | erro_2 1.0874 - custo 6.0743
# ÉPOCA  465 finalizada: erro_0 11.4842 | erro_1 5.5752 | erro_2 1.0692 - custo 6.0429
# ÉPOCA  466 finalizada: erro_0 11.4967 | erro_1 5.6361 | erro_2 1.0774 - custo 6.0701
# ÉPOCA  467 finalizada: erro_0 11.4661 | erro_1 5.6490 | erro_2 1.1227 - custo 6.0792
# ÉPOCA  468 finalizada: erro_0 11.4156 | erro_1 5.6417 | erro_2 1.0914 - custo 6.0496
# ÉPOCA  469 finalizada: erro_0 11.4419 | erro_1 5.5902 | erro_2 1.1046 - custo 6.0456
# ÉPOCA  470 finalizada: erro_0 11.4276 | erro_1 5.6319 | erro_2 1.1200 - custo 6.0599
# ÉPOCA  471 finalizada: erro_0 11.3669 | erro_1 5.5941 | erro_2 1.1078 - custo 6.0229
# ÉPOCA  472 finalizada: erro_0 11.4266 | erro_1 5.6059 | erro_2 1.0873 - custo 6.0399
# ÉPOCA  473 finalizada: erro_0 11.4193 | erro_1 5.6094 | erro_2 1.0958 - custo 6.0415
# ÉPOCA  474 finalizada: erro_0 11.7857 | erro_1 5.7614 | erro_2 1.1276 - custo 6.2249
# ÉPOCA  475 finalizada: erro_0 11.4855 | erro_1 5.5906 | erro_2 1.0631 - custo 6.0464
# ÉPOCA  476 finalizada: erro_0 11.3976 | erro_1 5.6344 | erro_2 1.1095 - custo 6.0472
# ÉPOCA  477 finalizada: erro_0 11.5380 | erro_1 5.6701 | erro_2 1.0953 - custo 6.1011
# ÉPOCA  478 finalizada: erro_0 11.3993 | erro_1 5.6227 | erro_2 1.0993 - custo 6.0404
# ÉPOCA  479 finalizada: erro_0 11.8262 | erro_1 5.8779 | erro_2 1.1661 - custo 6.2900
# ÉPOCA  480 finalizada: erro_0 11.5218 | erro_1 5.5784 | erro_2 1.0899 - custo 6.0634
# ÉPOCA  481 finalizada: erro_0 11.4232 | erro_1 5.5387 | erro_2 1.0568 - custo 6.0062
# ÉPOCA  482 finalizada: erro_0 11.3349 | erro_1 5.5757 | erro_2 1.0635 - custo 5.9914
# ÉPOCA  483 finalizada: erro_0 11.3365 | erro_1 5.5669 | erro_2 1.0598 - custo 5.9878
# ÉPOCA  484 finalizada: erro_0 11.4241 | erro_1 5.5938 | erro_2 1.0952 - custo 6.0377
# ÉPOCA  485 finalizada: erro_0 11.3174 | erro_1 5.5731 | erro_2 1.0616 - custo 5.9840
# ÉPOCA  486 finalizada: erro_0 11.4542 | erro_1 5.6014 | erro_2 1.0867 - custo 6.0474
# ÉPOCA  487 finalizada: erro_0 11.4491 | erro_1 5.5726 | erro_2 1.0921 - custo 6.0379
# ÉPOCA  488 finalizada: erro_0 11.4029 | erro_1 5.6900 | erro_2 1.1540 - custo 6.0823
# ÉPOCA  489 finalizada: erro_0 11.4288 | erro_1 5.6898 | erro_2 1.1412 - custo 6.0866
# ÉPOCA  490 finalizada: erro_0 11.4687 | erro_1 5.6531 | erro_2 1.1102 - custo 6.0773
# ÉPOCA  491 finalizada: erro_0 11.6224 | erro_1 5.6835 | erro_2 1.0862 - custo 6.1307
# ÉPOCA  492 finalizada: erro_0 11.3260 | erro_1 5.6176 | erro_2 1.0975 - custo 6.0137
# ÉPOCA  493 finalizada: erro_0 11.3576 | erro_1 5.5977 | erro_2 1.1110 - custo 6.0221
# ÉPOCA  494 finalizada: erro_0 11.3488 | erro_1 5.5759 | erro_2 1.0952 - custo 6.0066
# ÉPOCA  495 finalizada: erro_0 11.3297 | erro_1 5.5718 | erro_2 1.0648 - custo 5.9888
# ÉPOCA  496 finalizada: erro_0 11.4251 | erro_1 5.6627 | erro_2 1.1114 - custo 6.0664
# ÉPOCA  497 finalizada: erro_0 11.6846 | erro_1 5.7224 | erro_2 1.1117 - custo 6.1729
# ÉPOCA  498 finalizada: erro_0 11.3534 | erro_1 5.5625 | erro_2 1.0898 - custo 6.0019
# ÉPOCA  499 finalizada: erro_0 11.3764 | erro_1 5.5964 | erro_2 1.0984 - custo 6.0237
# ÉPOCA  500 finalizada: erro_0 11.3083 | erro_1 5.5938 | erro_2 1.0916 - custo 5.9979
# ÉPOCA  501 finalizada: erro_0 11.2985 | erro_1 5.5240 | erro_2 1.0641 - custo 5.9622
# ÉPOCA  502 finalizada: erro_0 11.8189 | erro_1 5.6850 | erro_2 1.0885 - custo 6.1975
# ÉPOCA  503 finalizada: erro_0 11.5128 | erro_1 5.6380 | erro_2 1.0941 - custo 6.0816
# ÉPOCA  504 finalizada: erro_0 11.3326 | erro_1 5.5678 | erro_2 1.0738 - custo 5.9914
# ÉPOCA  505 finalizada: erro_0 11.2750 | erro_1 5.5040 | erro_2 1.0727 - custo 5.9506
# ÉPOCA  506 finalizada: erro_0 11.3915 | erro_1 5.5458 | erro_2 1.0423 - custo 5.9932
# ÉPOCA  507 finalizada: erro_0 11.5542 | erro_1 5.6330 | erro_2 1.0885 - custo 6.0919
# ÉPOCA  508 finalizada: erro_0 11.3322 | erro_1 5.5955 | erro_2 1.0739 - custo 6.0005
# ÉPOCA  509 finalizada: erro_0 11.5297 | erro_1 5.6502 | erro_2 1.0802 - custo 6.0867
# ÉPOCA  510 finalizada: erro_0 11.1844 | erro_1 5.5659 | erro_2 1.0521 - custo 5.9341
# ...
# ÉPOCA 1831 finalizada: erro_0 10.9425 | erro_1 5.5289 | erro_2 1.1361 - custo 5.8692
# ÉPOCA 1832 finalizada: erro_0 10.9503 | erro_1 5.5246 | erro_2 1.1352 - custo 5.8701
# ÉPOCA 1833 finalizada: erro_0 10.9101 | erro_1 5.5127 | erro_2 1.1331 - custo 5.8520
# ÉPOCA 1834 finalizada: erro_0 10.9377 | erro_1 5.5197 | erro_2 1.1347 - custo 5.8640
# ÉPOCA 1835 finalizada: erro_0 11.7497 | erro_1 5.8990 | erro_2 1.2077 - custo 6.2855
# ÉPOCA 1836 finalizada: erro_0 11.9719 | erro_1 5.9407 | erro_2 1.2005 - custo 6.3710
# ÉPOCA 1837 finalizada: erro_0 11.9306 | erro_1 5.8323 | erro_2 1.1790 - custo 6.3140
# ÉPOCA 1838 finalizada: erro_0 11.9708 | erro_1 5.9087 | erro_2 1.1911 - custo 6.3568
# ÉPOCA 1839 finalizada: erro_0 11.9680 | erro_1 5.8855 | erro_2 1.1913 - custo 6.3483
# ÉPOCA 1840 finalizada: erro_0 12.0688 | erro_1 5.9534 | erro_2 1.1815 - custo 6.4012
# ÉPOCA 1841 finalizada: erro_0 11.9293 | erro_1 5.9206 | erro_2 1.1832 - custo 6.3444
# ÉPOCA 1842 finalizada: erro_0 11.8902 | erro_1 5.8904 | erro_2 1.1803 - custo 6.3203
# ÉPOCA 1843 finalizada: erro_0 11.8741 | erro_1 5.8940 | erro_2 1.1803 - custo 6.3161
# ÉPOCA 1844 finalizada: erro_0 11.8461 | erro_1 5.8840 | erro_2 1.1764 - custo 6.3021
# ÉPOCA 1845 finalizada: erro_0 11.8247 | erro_1 5.8757 | erro_2 1.1733 - custo 6.2912
# ÉPOCA 1846 finalizada: erro_0 11.8223 | erro_1 5.8822 | erro_2 1.1709 - custo 6.2918
# ÉPOCA 1847 finalizada: erro_0 11.8263 | erro_1 5.8690 | erro_2 1.1697 - custo 6.2883
# ÉPOCA 1848 finalizada: erro_0 11.8219 | erro_1 5.8668 | erro_2 1.1731 - custo 6.2873
# ÉPOCA 1849 finalizada: erro_0 11.8503 | erro_1 5.8725 | erro_2 1.1670 - custo 6.2966
# ÉPOCA 1850 finalizada: erro_0 11.8312 | erro_1 5.8739 | erro_2 1.1664 - custo 6.2905
# ÉPOCA 1851 finalizada: erro_0 11.8374 | erro_1 5.8690 | erro_2 1.1642 - custo 6.2902
# ÉPOCA 1852 finalizada: erro_0 11.8211 | erro_1 5.8620 | erro_2 1.1644 - custo 6.2825
# ÉPOCA 1853 finalizada: erro_0 11.8166 | erro_1 5.8608 | erro_2 1.1650 - custo 6.2808
# ÉPOCA 1854 finalizada: erro_0 11.8130 | erro_1 5.8594 | erro_2 1.1658 - custo 6.2794
# ÉPOCA 1855 finalizada: erro_0 11.8095 | erro_1 5.8574 | erro_2 1.1611 - custo 6.2760
# ÉPOCA 1856 finalizada: erro_0 11.8099 | erro_1 5.8550 | erro_2 1.1639 - custo 6.2762
# ÉPOCA 1857 finalizada: erro_0 11.8660 | erro_1 5.8679 | erro_2 1.1666 - custo 6.3002
# ÉPOCA 1858 finalizada: erro_0 11.8102 | erro_1 5.8530 | erro_2 1.1622 - custo 6.2751
# ÉPOCA 1859 finalizada: erro_0 11.8100 | erro_1 5.8536 | erro_2 1.1604 - custo 6.2746
# ÉPOCA 1860 finalizada: erro_0 11.8373 | erro_1 5.8597 | erro_2 1.1607 - custo 6.2859
# ÉPOCA 1861 finalizada: erro_0 11.8352 | erro_1 5.8549 | erro_2 1.1640 - custo 6.2847
# ÉPOCA 1862 finalizada: erro_0 11.8432 | erro_1 5.8612 | erro_2 1.1608 - custo 6.2884
# ÉPOCA 1863 finalizada: erro_0 11.8184 | erro_1 5.8548 | erro_2 1.1587 - custo 6.2773
# ÉPOCA 1864 finalizada: erro_0 11.8113 | erro_1 5.8568 | erro_2 1.1604 - custo 6.2762
# ÉPOCA 1865 finalizada: erro_0 11.8159 | erro_1 5.8552 | erro_2 1.1584 - custo 6.2765
# ÉPOCA 1866 finalizada: erro_0 11.8147 | erro_1 5.8510 | erro_2 1.1575 - custo 6.2744
# ÉPOCA 1867 finalizada: erro_0 11.8434 | erro_1 5.8609 | erro_2 1.1579 - custo 6.2874
# ÉPOCA 1868 finalizada: erro_0 11.8204 | erro_1 5.8461 | erro_2 1.1579 - custo 6.2748
# ÉPOCA 1869 finalizada: erro_0 11.8118 | erro_1 5.8503 | erro_2 1.1584 - custo 6.2735
# ÉPOCA 1870 finalizada: erro_0 11.8076 | erro_1 5.8525 | erro_2 1.1556 - custo 6.2719
# ÉPOCA 1871 finalizada: erro_0 11.8470 | erro_1 5.8549 | erro_2 1.1573 - custo 6.2864
# ÉPOCA 1872 finalizada: erro_0 11.8495 | erro_1 5.8631 | erro_2 1.1562 - custo 6.2896
# ÉPOCA 1873 finalizada: erro_0 11.8183 | erro_1 5.8560 | erro_2 1.1593 - custo 6.2778
# ÉPOCA 1874 finalizada: erro_0 11.8270 | erro_1 5.8565 | erro_2 1.1538 - custo 6.2791
# ÉPOCA 1875 finalizada: erro_0 11.8188 | erro_1 5.8538 | erro_2 1.1559 - custo 6.2761
# ÉPOCA 1876 finalizada: erro_0 11.8529 | erro_1 5.8452 | erro_2 1.1566 - custo 6.2849
# ÉPOCA 1877 finalizada: erro_0 11.8542 | erro_1 5.8437 | erro_2 1.1576 - custo 6.2852
# ÉPOCA 1878 finalizada: erro_0 11.8431 | erro_1 5.8344 | erro_2 1.1611 - custo 6.2795
# ÉPOCA 1879 finalizada: erro_0 11.8647 | erro_1 5.8412 | erro_2 1.1559 - custo 6.2873
# ÉPOCA 1880 finalizada: erro_0 11.8760 | erro_1 5.8427 | erro_2 1.1676 - custo 6.2954
# ÉPOCA 1881 finalizada: erro_0 11.8370 | erro_1 5.8282 | erro_2 1.1581 - custo 6.2744
# ÉPOCA 1882 finalizada: erro_0 11.8449 | erro_1 5.8348 | erro_2 1.1582 - custo 6.2793
# ÉPOCA 1883 finalizada: erro_0 11.8587 | erro_1 5.8371 | erro_2 1.1566 - custo 6.2841
# ÉPOCA 1884 finalizada: erro_0 11.8536 | erro_1 5.8411 | erro_2 1.1617 - custo 6.2854
# ÉPOCA 1885 finalizada: erro_0 11.8412 | erro_1 5.8324 | erro_2 1.1576 - custo 6.2771
# ÉPOCA 1886 finalizada: erro_0 11.8460 | erro_1 5.8321 | erro_2 1.1554 - custo 6.2779
# ÉPOCA 1887 finalizada: erro_0 11.8556 | erro_1 5.8339 | erro_2 1.1557 - custo 6.2817
# ÉPOCA 1888 finalizada: erro_0 11.8444 | erro_1 5.8310 | erro_2 1.1561 - custo 6.2772
# ÉPOCA 1889 finalizada: erro_0 11.8509 | erro_1 5.8337 | erro_2 1.1560 - custo 6.2802
# ÉPOCA 1890 finalizada: erro_0 11.8409 | erro_1 5.8300 | erro_2 1.1552 - custo 6.2754
# ÉPOCA 1891 finalizada: erro_0 11.8602 | erro_1 5.8377 | erro_2 1.1570 - custo 6.2849
# ÉPOCA 1892 finalizada: erro_0 11.8498 | erro_1 5.8317 | erro_2 1.1537 - custo 6.2784
# ÉPOCA 1893 finalizada: erro_0 11.8538 | erro_1 5.8353 | erro_2 1.1597 - custo 6.2829
# ÉPOCA 1894 finalizada: erro_0 11.8469 | erro_1 5.8315 | erro_2 1.1529 - custo 6.2771
# ÉPOCA 1895 finalizada: erro_0 11.8655 | erro_1 5.8352 | erro_2 1.1573 - custo 6.2860
# ÉPOCA 1896 finalizada: erro_0 11.8616 | erro_1 5.8359 | erro_2 1.1550 - custo 6.2842
# ÉPOCA 1897 finalizada: erro_0 11.8637 | erro_1 5.8335 | erro_2 1.1574 - custo 6.2849
# ÉPOCA 1898 finalizada: erro_0 11.8976 | erro_1 5.8376 | erro_2 1.1555 - custo 6.2969
# ÉPOCA 1899 finalizada: erro_0 11.9682 | erro_1 5.8664 | erro_2 1.1792 - custo 6.3379
# ÉPOCA 1900 finalizada: erro_0 11.8731 | erro_1 5.8443 | erro_2 1.1530 - custo 6.2901
# ÉPOCA 1901 finalizada: erro_0 11.8505 | erro_1 5.8307 | erro_2 1.1578 - custo 6.2796
# ÉPOCA 1902 finalizada: erro_0 11.8430 | erro_1 5.8298 | erro_2 1.1595 - custo 6.2774
# ÉPOCA 1903 finalizada: erro_0 11.8446 | erro_1 5.8327 | erro_2 1.1557 - custo 6.2777
# ÉPOCA 1904 finalizada: erro_0 11.8436 | erro_1 5.8308 | erro_2 1.1542 - custo 6.2762
# ÉPOCA 1905 finalizada: erro_0 11.8541 | erro_1 5.8394 | erro_2 1.1576 - custo 6.2837
# ÉPOCA 1906 finalizada: erro_0 11.8452 | erro_1 5.8313 | erro_2 1.1543 - custo 6.2769
# ÉPOCA 1907 finalizada: erro_0 11.8427 | erro_1 5.8327 | erro_2 1.1582 - custo 6.2778
# ÉPOCA 1908 finalizada: erro_0 11.8439 | erro_1 5.8312 | erro_2 1.1561 - custo 6.2771
# ÉPOCA 1909 finalizada: erro_0 11.8671 | erro_1 5.8394 | erro_2 1.1583 - custo 6.2882
# ÉPOCA 1910 finalizada: erro_0 11.8351 | erro_1 5.8294 | erro_2 1.1531 - custo 6.2725
# ÉPOCA 1911 finalizada: erro_0 11.8415 | erro_1 5.8358 | erro_2 1.1579 - custo 6.2784
# ÉPOCA 1912 finalizada: erro_0 11.8390 | erro_1 5.8328 | erro_2 1.1528 - custo 6.2749
# ÉPOCA 1913 finalizada: erro_0 11.8703 | erro_1 5.8463 | erro_2 1.1540 - custo 6.2902
# ÉPOCA 1914 finalizada: erro_0 11.8448 | erro_1 5.8313 | erro_2 1.1548 - custo 6.2770
# ÉPOCA 1915 finalizada: erro_0 11.8440 | erro_1 5.8330 | erro_2 1.1563 - custo 6.2778
# ÉPOCA 1916 finalizada: erro_0 11.8465 | erro_1 5.8369 | erro_2 1.1531 - custo 6.2789
# ÉPOCA 1917 finalizada: erro_0 11.8509 | erro_1 5.8390 | erro_2 1.1567 - custo 6.2822
# ÉPOCA 1918 finalizada: erro_0 11.8925 | erro_1 5.8464 | erro_2 1.1542 - custo 6.2977
# ÉPOCA 1919 finalizada: erro_0 11.8495 | erro_1 5.8375 | erro_2 1.1558 - custo 6.2810
# ÉPOCA 1920 finalizada: erro_0 11.8461 | erro_1 5.8304 | erro_2 1.1589 - custo 6.2785
# ÉPOCA 1921 finalizada: erro_0 11.8488 | erro_1 5.8382 | erro_2 1.1535 - custo 6.2802
# ÉPOCA 1922 finalizada: erro_0 11.8427 | erro_1 5.8337 | erro_2 1.1563 - custo 6.2776
# ÉPOCA 1923 finalizada: erro_0 11.8407 | erro_1 5.8313 | erro_2 1.1539 - custo 6.2753
# ÉPOCA 1924 finalizada: erro_0 11.8373 | erro_1 5.8323 | erro_2 1.1546 - custo 6.2747
# ÉPOCA 1925 finalizada: erro_0 11.8561 | erro_1 5.8443 | erro_2 1.1572 - custo 6.2858
# ÉPOCA 1926 finalizada: erro_0 11.8474 | erro_1 5.8340 | erro_2 1.1580 - custo 6.2798
# ÉPOCA 1927 finalizada: erro_0 11.8404 | erro_1 5.8304 | erro_2 1.1528 - custo 6.2745
# ÉPOCA 1928 finalizada: erro_0 11.8377 | erro_1 5.8296 | erro_2 1.1536 - custo 6.2736
# ÉPOCA 1929 finalizada: erro_0 11.8431 | erro_1 5.8299 | erro_2 1.1620 - custo 6.2784
# ÉPOCA 1930 finalizada: erro_0 11.8380 | erro_1 5.8330 | erro_2 1.1532 - custo 6.2747
# ÉPOCA 1931 finalizada: erro_0 11.8708 | erro_1 5.8422 | erro_2 1.1533 - custo 6.2888
# ÉPOCA 1932 finalizada: erro_0 11.8396 | erro_1 5.8306 | erro_2 1.1537 - custo 6.2746
# ÉPOCA 1933 finalizada: erro_0 11.8424 | erro_1 5.8293 | erro_2 1.1580 - custo 6.2765
# ÉPOCA 1934 finalizada: erro_0 11.8373 | erro_1 5.8315 | erro_2 1.1522 - custo 6.2737
# ÉPOCA 1935 finalizada: erro_0 11.8421 | erro_1 5.8350 | erro_2 1.1558 - custo 6.2776
# ÉPOCA 1936 finalizada: erro_0 11.8415 | erro_1 5.8291 | erro_2 1.1521 - custo 6.2742
# ÉPOCA 1937 finalizada: erro_0 11.8441 | erro_1 5.8306 | erro_2 1.1559 - custo 6.2769
# ÉPOCA 1938 finalizada: erro_0 11.8403 | erro_1 5.8312 | erro_2 1.1541 - custo 6.2752
# ÉPOCA 1939 finalizada: erro_0 11.8470 | erro_1 5.8317 | erro_2 1.1554 - custo 6.2780
# ÉPOCA 1940 finalizada: erro_0 11.8331 | erro_1 5.8304 | erro_2 1.1517 - custo 6.2718
# ÉPOCA 1941 finalizada: erro_0 11.8425 | erro_1 5.8293 | erro_2 1.1534 - custo 6.2750
# ÉPOCA 1942 finalizada: erro_0 11.8734 | erro_1 5.8382 | erro_2 1.1519 - custo 6.2878
# ÉPOCA 1943 finalizada: erro_0 11.8357 | erro_1 5.8499 | erro_2 1.1494 - custo 6.2784
# ÉPOCA 1944 finalizada: erro_0 11.9191 | erro_1 5.8431 | erro_2 1.1528 - custo 6.3050
# ÉPOCA 1945 finalizada: erro_0 11.9496 | erro_1 5.8479 | erro_2 1.1602 - custo 6.3193
# ÉPOCA 1946 finalizada: erro_0 11.9994 | erro_1 5.8637 | erro_2 1.1633 - custo 6.3421
# ÉPOCA 1947 finalizada: erro_0 11.9467 | erro_1 5.8538 | erro_2 1.1631 - custo 6.3212
# ÉPOCA 1948 finalizada: erro_0 11.8795 | erro_1 5.8318 | erro_2 1.1581 - custo 6.2898
# ÉPOCA 1949 finalizada: erro_0 11.8604 | erro_1 5.8255 | erro_2 1.1544 - custo 6.2801
# ÉPOCA 1950 finalizada: erro_0 11.9215 | erro_1 5.8557 | erro_2 1.1624 - custo 6.3132
# ÉPOCA 1951 finalizada: erro_0 11.8386 | erro_1 5.8314 | erro_2 1.1530 - custo 6.2743
# ÉPOCA 1952 finalizada: erro_0 11.8611 | erro_1 5.8338 | erro_2 1.1519 - custo 6.2823
# ÉPOCA 1953 finalizada: erro_0 11.8413 | erro_1 5.8318 | erro_2 1.1535 - custo 6.2755
# ÉPOCA 1954 finalizada: erro_0 11.8464 | erro_1 5.8319 | erro_2 1.1554 - custo 6.2779
# ÉPOCA 1955 finalizada: erro_0 11.8499 | erro_1 5.8299 | erro_2 1.1533 - custo 6.2777
# ÉPOCA 1956 finalizada: erro_0 11.8461 | erro_1 5.8332 | erro_2 1.1512 - custo 6.2768
# ÉPOCA 1957 finalizada: erro_0 11.8560 | erro_1 5.8374 | erro_2 1.1512 - custo 6.2815
# ÉPOCA 1958 finalizada: erro_0 11.8510 | erro_1 5.8318 | erro_2 1.1540 - custo 6.2789
# ÉPOCA 1959 finalizada: erro_0 11.8507 | erro_1 5.8340 | erro_2 1.1546 - custo 6.2797
# ÉPOCA 1960 finalizada: erro_0 11.9054 | erro_1 5.8599 | erro_2 1.1551 - custo 6.3068
# ÉPOCA 1961 finalizada: erro_0 11.8329 | erro_1 5.8312 | erro_2 1.1549 - custo 6.2730
# ÉPOCA 1962 finalizada: erro_0 11.8536 | erro_1 5.8422 | erro_2 1.1545 - custo 6.2834
# ÉPOCA 1963 finalizada: erro_0 11.8781 | erro_1 5.8519 | erro_2 1.1612 - custo 6.2971
# ÉPOCA 1964 finalizada: erro_0 11.8348 | erro_1 5.8271 | erro_2 1.1519 - custo 6.2713
# ÉPOCA 1965 finalizada: erro_0 11.8513 | erro_1 5.8385 | erro_2 1.1543 - custo 6.2814
# ÉPOCA 1966 finalizada: erro_0 11.8440 | erro_1 5.8286 | erro_2 1.1578 - custo 6.2768
# ÉPOCA 1967 finalizada: erro_0 11.8585 | erro_1 5.8302 | erro_2 1.1536 - custo 6.2807
# ÉPOCA 1968 finalizada: erro_0 11.8593 | erro_1 5.8353 | erro_2 1.1500 - custo 6.2815
# ÉPOCA 1969 finalizada: erro_0 11.8742 | erro_1 5.8420 | erro_2 1.1500 - custo 6.2887
# ÉPOCA 1970 finalizada: erro_0 11.8705 | erro_1 5.8562 | erro_2 1.1502 - custo 6.2923
# ÉPOCA 1971 finalizada: erro_0 11.8902 | erro_1 5.8579 | erro_2 1.1515 - custo 6.2999
# ÉPOCA 1972 finalizada: erro_0 11.8718 | erro_1 5.8468 | erro_2 1.1474 - custo 6.2887
# ÉPOCA 1973 finalizada: erro_0 11.8590 | erro_1 5.8518 | erro_2 1.1529 - custo 6.2879
# ÉPOCA 1974 finalizada: erro_0 11.8663 | erro_1 5.8461 | erro_2 1.1516 - custo 6.2880
# ÉPOCA 1975 finalizada: erro_0 11.8763 | erro_1 5.8577 | erro_2 1.1435 - custo 6.2925
# ÉPOCA 1976 finalizada: erro_0 11.8619 | erro_1 5.8509 | erro_2 1.1432 - custo 6.2853
# ÉPOCA 1977 finalizada: erro_0 11.8483 | erro_1 5.8421 | erro_2 1.1504 - custo 6.2803
# ÉPOCA 1978 finalizada: erro_0 11.8563 | erro_1 5.8346 | erro_2 1.1527 - custo 6.2812
# ÉPOCA 1979 finalizada: erro_0 11.8645 | erro_1 5.8378 | erro_2 1.1534 - custo 6.2852
# ÉPOCA 1980 finalizada: erro_0 11.8492 | erro_1 5.8387 | erro_2 1.1500 - custo 6.2793
# ÉPOCA 1981 finalizada: erro_0 11.8732 | erro_1 5.8338 | erro_2 1.1506 - custo 6.2859
# ÉPOCA 1982 finalizada: erro_0 11.8606 | erro_1 5.8315 | erro_2 1.1523 - custo 6.2815
# ÉPOCA 1983 finalizada: erro_0 11.8439 | erro_1 5.8304 | erro_2 1.1501 - custo 6.2748
# ÉPOCA 1984 finalizada: erro_0 11.8444 | erro_1 5.8272 | erro_2 1.1518 - custo 6.2744
# ÉPOCA 1985 finalizada: erro_0 11.8325 | erro_1 5.8269 | erro_2 1.1550 - custo 6.2715
# ÉPOCA 1986 finalizada: erro_0 11.8546 | erro_1 5.8417 | erro_2 1.1575 - custo 6.2846
# ÉPOCA 1987 finalizada: erro_0 11.8389 | erro_1 5.8275 | erro_2 1.1485 - custo 6.2716
# ÉPOCA 1988 finalizada: erro_0 11.8386 | erro_1 5.8347 | erro_2 1.1517 - custo 6.2750
# ÉPOCA 1989 finalizada: erro_0 11.8385 | erro_1 5.8290 | erro_2 1.1509 - custo 6.2728
# ÉPOCA 1990 finalizada: erro_0 11.8560 | erro_1 5.8381 | erro_2 1.1531 - custo 6.2824
# ÉPOCA 1991 finalizada: erro_0 11.8452 | erro_1 5.8347 | erro_2 1.1594 - custo 6.2798
# ÉPOCA 1992 finalizada: erro_0 11.8421 | erro_1 5.8313 | erro_2 1.1507 - custo 6.2747
# ÉPOCA 1993 finalizada: erro_0 11.8521 | erro_1 5.8372 | erro_2 1.1512 - custo 6.2802
# ÉPOCA 1994 finalizada: erro_0 11.8516 | erro_1 5.8411 | erro_2 1.1513 - custo 6.2813
# ÉPOCA 1995 finalizada: erro_0 11.8560 | erro_1 5.8341 | erro_2 1.1522 - custo 6.2808
# ÉPOCA 1996 finalizada: erro_0 11.8937 | erro_1 5.8274 | erro_2 1.1512 - custo 6.2908
# ÉPOCA 1997 finalizada: erro_0 11.9151 | erro_1 5.8460 | erro_2 1.1516 - custo 6.3043
# ÉPOCA 1998 finalizada: erro_0 11.8908 | erro_1 5.8377 | erro_2 1.1540 - custo 6.2941
# ÉPOCA 1999 finalizada: erro_0 11.8424 | erro_1 5.8302 | erro_2 1.1506 - custo 6.2744
# ÉPOCA 2000 finalizada: erro_0 11.8409 | erro_1 5.8335 | erro_2 1.1523 - custo 6.2756

# %% [markdown]
# ## Model Evaluation

# %%
regressor.eval()
# Out:
# regressor_torch(
#   (dense0): Linear(in_features=61, out_features=32, bias=True)
#   (dense1): Linear(in_features=32, out_features=32, bias=True)
#   (activation): Sigmoid()
#   (output): Linear(in_features=32, out_features=3, bias=True)
# )

# %%
previsores = previsores.to(device)
previsoes = regressor.forward(previsores)

# %%
previsoes
# Out:
# tensor([[3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [4.1479, 2.6767, 0.2834],
#         [3.1723, 2.2986, 0.6172],
#         [4.1479, 2.6767, 0.2834],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1523, 2.5452, 0.0647],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [4.1439, 2.6748, 0.2842],
#         [4.1479, 2.6767, 0.2834],
#         [4.1479, 2.6767, 0.2834],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [4.1479, 2.6767, 0.2834],
#         [3.1723, 2.2986, 0.6172],
#         [4.1479, 2.6767, 0.2834],
#         [4.1183, 2.6622, 0.2894],
#         [4.1479, 2.6767, 0.2834],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [4.1454, 2.6755, 0.2839],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [4.1478, 2.6766, 0.2834],
#         [3.1723, 2.2986, 0.6172],
#         [4.1479, 2.6767, 0.2834],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [4.1479, 2.6767, 0.2834],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.3010, 2.3353, 0.5566],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [4.1479, 2.6767, 0.2834],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1728, 2.2988, 0.6170],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [4.1479, 2.6767, 0.2834],
#         [4.1479, 2.6767, 0.2834],
#         [3.1723, 2.2986, 0.6172],
#         [4.1479, 2.6767, 0.2834],
#         [3.1723, 2.2986, 0.6172],
#         [3.2218, 2.3126, 0.5940],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [4.1477, 2.6766, 0.2834],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [4.1479, 2.6767, 0.2834],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [4.1479, 2.6767, 0.2834],
#         [3.1523, 2.5452, 0.0647],
#         [4.1479, 2.6767, 0.2834],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [4.1479, 2.6767, 0.2834],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.0749, 2.3992, 0.4855],
#         [4.1455, 2.6755, 0.2839],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1523, 2.5452, 0.0647],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1727, 2.2987, 0.6170],
#         [4.1479, 2.6767, 0.2834],
#         [3.1723, 2.2986, 0.6172],
#         [4.1479, 2.6767, 0.2834],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [4.1479, 2.6767, 0.2834],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [4.1479, 2.6767, 0.2834],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [4.1479, 2.6767, 0.2834],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1523, 2.5452, 0.0647],
#         [3.1723, 2.2986, 0.6172],
#         [4.1479, 2.6767, 0.2834],
#         [3.1724, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1523, 2.5452, 0.0647],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [4.1479, 2.6767, 0.2834],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [4.1479, 2.6767, 0.2834],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [4.1476, 2.6765, 0.2835],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172],
#         [3.1723, 2.2986, 0.6172]], device='cuda:0', grad_fn=<AddmmBackward0>)

# %%
previsoes = previsoes.cpu().detach().numpy()

# %%
previsoes
# Out:
# array([[3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [4.1478987 , 2.6766982 , 0.2834013 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [4.1478987 , 2.6766982 , 0.2834013 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1523118 , 2.5452256 , 0.06469904],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [4.143928  , 2.6747527 , 0.28419787],
#        [4.1478987 , 2.6766982 , 0.2834013 ],
#        [4.1478987 , 2.6766982 , 0.2834013 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722624 , 2.2986195 , 0.617242  ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [4.147887  , 2.676693  , 0.28340346],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [4.1478987 , 2.6766982 , 0.2834013 ],
#        [4.1182876 , 2.662241  , 0.2894191 ],
#        [4.1478987 , 2.6766982 , 0.2834013 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.61724246],
#        [4.14538   , 2.6754634 , 0.28390622],
#        [3.1722965 , 2.298629  , 0.61722636],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [4.1477933 , 2.6766467 , 0.28342223],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [4.1478987 , 2.6766982 , 0.2834013 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [4.1478987 , 2.6766982 , 0.2834013 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.300992  , 2.3352866 , 0.55659103],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.172282  , 2.298625  , 0.6172327 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [4.1478987 , 2.6766982 , 0.2834013 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1728268 , 2.2987804 , 0.6169816 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [4.1478987 , 2.6766982 , 0.2834013 ],
#        [4.1478987 , 2.6766982 , 0.2834013 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [4.1478987 , 2.6766982 , 0.2834013 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.221809  , 2.3126304 , 0.5940347 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [4.147718  , 2.6766098 , 0.28343743],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.172294  , 2.2986283 , 0.61722726],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [4.147896  , 2.676697  , 0.28340167],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [4.1478987 , 2.6766982 , 0.2834013 ],
#        [3.1523116 , 2.5452256 , 0.06469919],
#        [4.1478987 , 2.6766982 , 0.2834013 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [4.1478987 , 2.6766982 , 0.2834013 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.0748668 , 2.3991518 , 0.48546767],
#        [4.1454787 , 2.6755123 , 0.28388643],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1523118 , 2.5452256 , 0.06469904],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1726818 , 2.298739  , 0.6170484 ],
#        [4.1478987 , 2.6766982 , 0.2834013 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [4.1478963 , 2.6766973 , 0.2834016 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [4.1478987 , 2.6766982 , 0.2834013 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722655 , 2.2986202 , 0.6172405 ],
#        [4.1478987 , 2.6766982 , 0.2834013 ],
#        [3.1722608 , 2.298619  , 0.61724246],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [4.1478987 , 2.6766982 , 0.2834013 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1523118 , 2.5452256 , 0.06469904],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [4.1478977 , 2.6766977 , 0.28340137],
#        [3.1723566 , 2.2986462 , 0.61719847],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1523118 , 2.5452256 , 0.06469904],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722991 , 2.2986302 , 0.6172248 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [4.1478987 , 2.6766982 , 0.2834013 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [4.1478987 , 2.6766982 , 0.2834013 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [4.147558  , 2.6765316 , 0.28346956],
#        [3.1722624 , 2.2986195 , 0.617242  ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ],
#        [3.1722612 , 2.298619  , 0.6172426 ]], dtype=float32)

# %%
previsoes.mean(axis = 0)
# Out:
# array([3.2930443, 2.3508067, 0.5643202], dtype=float32)

# %%
vendas.mean(axis = 0)
# Out:
# tensor([3.2838, 2.3505, 0.5862])

# %%
fig, ax = plt.subplots(1, 3, figsize=(10,5))
for i in range(3):
  ax[i].plot(vendas[:, i])
  ax[i].plot(previsoes[:, i])
  ax[i].legend(['Valores reais', 'Previsões'])
  ax[i].set_title(base.columns[4 + i])
