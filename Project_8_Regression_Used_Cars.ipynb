# %% [markdown]
# <a href="https://colab.research.google.com/github/Kaua-Rbs/Deep-Learning-From-A-To-Z-With-Pytorch-And-Python/blob/main/Project_8_Regression_Used_Cars.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Project 8: Regression - Used Cars

# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import torch
import numpy as np
import seaborn as sns
from torch import nn, optim
import torch.nn.functional as F
torch.__version__
# Out:
# '2.3.0+cu121'

# %% [markdown]
# ## Database

# %%
np.random.seed(123)
torch.manual_seed(123)

# %%
base = pd.read_csv('autos.csv', encoding = 'ISO-8859-1')

# %%
base.head()
# Out:
#            dateCrawled                            name  seller offerType  \
# 0  2016-03-24 11:52:17                      Golf_3_1.6  privat   Angebot
# 1  2016-03-24 10:58:45            A5_Sportback_2.7_Tdi  privat   Angebot
# 2  2016-03-14 12:52:21  Jeep_Grand_Cherokee_"Overland"  privat   Angebot
# 3  2016-03-17 16:54:04              GOLF_4_1_4__3TÜRER  privat   Angebot
# 4  2016-03-31 17:25:20  Skoda_Fabia_1.4_TDI_PD_Classic  privat   Angebot
#
#    price abtest vehicleType  yearOfRegistration    gearbox  powerPS  model  \
# 0    480   test         NaN                1993    manuell        0   golf
# 1  18300   test       coupe                2011    manuell      190    NaN
# 2   9800   test         suv                2004  automatik      163  grand
# 3   1500   test  kleinwagen                2001    manuell       75   golf
# 4   3600   test  kleinwagen                2008    manuell       69  fabia
#
#    kilometer  monthOfRegistration fuelType       brand notRepairedDamage  \
# ...

# %%
base.shape
# Out:
# (371528, 15)

# %%
base = base.drop('dateCrawled', axis = 1)
base = base.drop('dateCreated', axis = 1)
base = base.drop('nrOfPictures', axis = 1)
base = base.drop('postalCode', axis = 1)
base = base.drop('lastSeen', axis = 1)

# %%
base.shape
# Out:
# (371528, 15)

# %%
base['name'].value_counts()
# Out:
# name
# Ford_Fiesta                                              657
# BMW_318i                                                 627
# Opel_Corsa                                               622
# Volkswagen_Golf_1.4                                      603
# BMW_316i                                                 523
#                                                         ...
# Audi_A4_Avant_Klima_Gruene_Plakette_TÜV_&AU_NEU_XENON      1
# Renault_clio_in_gold_450VB_!!                              1
# Fiat_Doblo_1.6_Multijet                                    1
# Renault_Laguna_1                                           1
# BMW_M135i_vollausgestattet_NP_52.720____Euro               1
# Name: count, Length: 233531, dtype: int64

# %%
base = base.drop('name', axis = 1)

# %%
base['seller'].value_counts()
# Out:
# seller
# privat        371525
# gewerblich         3
# Name: count, dtype: int64

# %%
base = base.drop('seller', axis = 1)

# %%
base['offerType'].value_counts()
# Out:
# offerType
# Angebot    371516
# Gesuch         12
# Name: count, dtype: int64

# %%
base = base.drop('offerType', axis = 1)

# %%
base.head()
# Out:
#    price abtest vehicleType  yearOfRegistration    gearbox  powerPS  model  \
# 0    480   test         NaN                1993    manuell        0   golf
# 1  18300   test       coupe                2011    manuell      190    NaN
# 2   9800   test         suv                2004  automatik      163  grand
# 3   1500   test  kleinwagen                2001    manuell       75   golf
# 4   3600   test  kleinwagen                2008    manuell       69  fabia
#
#    kilometer  monthOfRegistration fuelType       brand notRepairedDamage
# 0     150000                    0   benzin  volkswagen               NaN
# 1     125000                    5   diesel        audi                ja
# 2     125000                    8   diesel        jeep               NaN
# 3     150000                    6   benzin  volkswagen              nein
# 4      90000                    7   diesel       skoda              nein

# %%
i1 = base.loc[base.price <= 10]

# %%
i1.shape
# Out:
# (12118, 12)

# %%
base = base[base.price > 10]

# %%
base.shape
# Out:
# (359410, 12)

# %%
i2 = base.loc[base.price > 350000]

# %%
i2.shape
# Out:
# (115, 12)

# %%
base = base.loc[base.price < 350000]

# %%
base.shape
# Out:
# (359291, 12)

# %%
sns.heatmap(base.isnull())
# Out:
# <Axes: >

# %%
base.loc[pd.isnull(base['vehicleType'])]
# Out:
#         price   abtest vehicleType  yearOfRegistration    gearbox  powerPS  \
# 0         480     test         NaN                1993    manuell        0
# 16        300     test         NaN                2016        NaN       60
# 22       2900     test         NaN                2018    manuell       90
# 26       5555  control         NaN                2017    manuell      125
# 31        899  control         NaN                2016    manuell       60
# ...       ...      ...         ...                 ...        ...      ...
# 371495    180  control         NaN                1995        NaN        0
# 371504   2600  control         NaN                2005  automatik        0
# 371509   1900     test         NaN                2000    manuell      110
# 371519   5250  control         NaN                2016  automatik      150
# 371523   2200     test         NaN                2005        NaN        0
#
# ...

# %%
base['vehicleType'].value_counts() # limousine
# Out:
# vehicleType
# limousine     93614
# kleinwagen    78014
# kombi         65921
# bus           29699
# cabrio        22509
# coupe         18386
# suv           14477
# andere         3125
# Name: count, dtype: int64

# %%
base.loc[pd.isnull(base['gearbox'])]
# Out:
#         price   abtest vehicleType  yearOfRegistration gearbox  powerPS  \
# 15        450     test  kleinwagen                1910     NaN        0
# 16        300     test         NaN                2016     NaN       60
# 32        245     test   limousine                1994     NaN        0
# 37       1500     test         NaN                2016     NaN        0
# 70       1200     test       coupe                2001     NaN        0
# ...       ...      ...         ...                 ...     ...      ...
# 371443   3300  control       kombi                2006     NaN        0
# 371460   3500  control         NaN                1995     NaN        0
# 371486    350  control  kleinwagen                1996     NaN       65
# 371495    180  control         NaN                1995     NaN        0
# 371523   2200     test         NaN                2005     NaN        0
#
#          model  kilometer  monthOfRegistration fuelType           brand  \
# ...

# %%
base['gearbox'].value_counts() # manuell
# Out:
# gearbox
# manuell      266547
# automatik     75508
# Name: count, dtype: int64

# %%
base.loc[pd.isnull(base['model'])]
# Out:
#         price   abtest vehicleType  yearOfRegistration    gearbox  powerPS  \
# 1       18300     test       coupe                2011    manuell      190
# 83        350  control  kleinwagen                1997    manuell       54
# 139      1450  control   limousine                1992    manuell      136
# 156      6799  control  kleinwagen                2009        NaN       60
# 165       500  control  kleinwagen                1999    manuell        0
# ...       ...      ...         ...                 ...        ...      ...
# 371399    560  control  kleinwagen                2001  automatik      170
# 371476   9400  control       kombi                2007    manuell      200
# 371495    180  control         NaN                1995        NaN        0
# 371509   1900     test         NaN                2000    manuell      110
# 371523   2200     test         NaN                2005        NaN        0
#
# ...

# %%
base['model'].value_counts() # golf
# Out:
# model
# golf               28989
# andere             25560
# 3er                19905
# polo               12604
# corsa              12149
#                    ...
# serie_2                8
# rangerover             6
# serie_3                3
# serie_1                1
# discovery_sport        1
# Name: count, Length: 251, dtype: int64

# %%
base.loc[pd.isnull(base['fuelType'])]
# Out:
#         price   abtest vehicleType  yearOfRegistration    gearbox  powerPS  \
# 9         999     test  kleinwagen                1998    manuell      101
# 13       2500  control       kombi                2004    manuell      131
# 26       5555  control         NaN                2017    manuell      125
# 36       1600  control      andere                1991    manuell       75
# 41       7500  control   limousine                2002  automatik      306
# ...       ...      ...         ...                 ...        ...      ...
# 371496   3850     test      cabrio                2006    manuell      108
# 371504   2600  control         NaN                2005  automatik        0
# 371509   1900     test         NaN                2000    manuell      110
# 371519   5250  control         NaN                2016  automatik      150
# 371523   2200     test         NaN                2005        NaN        0
#
# ...

# %%
base['fuelType'].value_counts() # benzin
# Out:
# fuelType
# benzin     217582
# diesel     106002
# lpg          5222
# cng           557
# hybrid        271
# andere        165
# elektro       101
# Name: count, dtype: int64

# %%
base.loc[pd.isnull(base['notRepairedDamage'])]
# Out:
#         price   abtest vehicleType  yearOfRegistration    gearbox  powerPS  \
# 0         480     test         NaN                1993    manuell        0
# 2        9800     test         suv                2004  automatik      163
# 8       14500  control         bus                2014    manuell      125
# 9         999     test  kleinwagen                1998    manuell      101
# 12        999  control       kombi                1995    manuell      115
# ...       ...      ...         ...                 ...        ...      ...
# 371507   5999     test       kombi                2005    manuell      140
# 371514    999  control      cabrio                2000    manuell       95
# 371515   1690     test       kombi                2004    manuell       55
# 371523   2200     test         NaN                2005        NaN        0
# 371526   3400     test       kombi                2002    manuell      100
#
# ...

# %%
base['notRepairedDamage'].value_counts() # nein
# Out:
# notRepairedDamage
# nein    259301
# ja       34004
# Name: count, dtype: int64

# %%
base.loc[pd.isnull(base['price'])]
# Out:
# Empty DataFrame
# Columns: [price, abtest, vehicleType, yearOfRegistration, gearbox, powerPS, model, kilometer, monthOfRegistration, fuelType, brand, notRepairedDamage]
# Index: []

# %%
valores = {'vehicleType': 'limousine', 'gearbox': 'manuell',
           'model': 'golf', 'fuelType': 'benzin',
           'notRepairedDamage': 'nein'}
base = base.fillna(value = valores)

# %%
base.loc[pd.isnull(base['notRepairedDamage'])]
# Out:
# Empty DataFrame
# Columns: [price, abtest, vehicleType, yearOfRegistration, gearbox, powerPS, model, kilometer, monthOfRegistration, fuelType, brand, notRepairedDamage]
# Index: []

# %%
previsores = base.iloc[:, 1:13].values
preco_real = base.iloc[:, 0].values

# %%
previsores.shape
# Out:
# (359291, 11)

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
# 1 0 0
# 0 1 0
# 0 0 1

# %%
onehotencoder = ColumnTransformer(transformers = [("OneHot", OneHotEncoder(),
                                                   [0,1,3,5,8,9,10])],
                                  remainder = 'passthrough')
previsores = onehotencoder.fit_transform(previsores).toarray()

# %%
previsores.shape
# Out:
# (359291, 316)

# %%
previsores[0]
# Out:
# array([0.000e+00, 1.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 1.000e+00, 0.000e+00, 0.000e+00, 1.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
# ...

# %%
previsores = torch.tensor(previsores, dtype = torch.float)
preco_real = torch.tensor(preco_real, dtype = torch.float).view(-1, 1)

# %%
type(previsores)
# Out:
# torch.Tensor

# %%
preco_real.shape
# Out:
# torch.Size([359291, 1])

# %% [markdown]
# ## Model Structuring

# %%
# 316 -> 158 -> 158 -> 1
# (entradas + saídas) / 2 = (316 + 1) / 2
regressor = nn.Sequential(nn.Linear(316, 158),
                          nn.ReLU(),
                          nn.Linear(158, 158),
                          nn.ReLU(),
                          nn.Linear(158, 1))

# %%
criterion = nn.L1Loss()

# %%
optimizer = optim.Adam(regressor.parameters())

# %%
dataset = torch.utils.data.TensorDataset(previsores, preco_real)
train_loader = torch.utils.data.DataLoader(dataset, batch_size=300, shuffle=True)

# %% [markdown]
# ## Model Training

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
device
# Out:
# 'cuda'

# %%
regressor.to(device)
# Out:
# Sequential(
#   (0): Linear(in_features=316, out_features=158, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=158, out_features=158, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=158, out_features=1, bias=True)
# )

# %%
for epoch in range(100):
  running_loss = 0.
  running_mae = 0.

  for i, data in enumerate(train_loader):
    inputs, labels = data

    inputs, labels = inputs.to(device), labels.to(device)

    optimizer.zero_grad()

    outputs = regressor.forward(inputs)

    mae = F.l1_loss(outputs, labels).item()

    running_mae += mae

    loss = criterion(outputs, labels)
    loss.backward()

    optimizer.step()

    running_loss += loss.item()

    print('\rÉpoca {:3d} - Loop {:3d} de {:3d}: perda {:06.2f} - MAE {:06.2f}'.format(epoch+1,
                                                                                      i + 1,
                                                                                      len(preco_real)//300,
                                                                                      loss, mae))
  print('ÉPOCA {:3d} finalizada: perda {:0.5f} - MAE {:0.5f} '.format(epoch+1,
                                                                      running_loss/len(train_loader),
                                                                      running_mae/len(train_loader)))
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
# Época  96 - Loop 996 de 1197: perda 2123.04 - MAE 2123.04
# Época  96 - Loop 997 de 1197: perda 2067.87 - MAE 2067.87
# Época  96 - Loop 998 de 1197: perda 1846.16 - MAE 1846.16
# Época  96 - Loop 999 de 1197: perda 2104.92 - MAE 2104.92
# Época  96 - Loop 1000 de 1197: perda 2014.87 - MAE 2014.87
# Época  96 - Loop 1001 de 1197: perda 1967.91 - MAE 1967.91
# Época  96 - Loop 1002 de 1197: perda 2083.63 - MAE 2083.63
# Época  96 - Loop 1003 de 1197: perda 2222.57 - MAE 2222.57
# Época  96 - Loop 1004 de 1197: perda 2000.47 - MAE 2000.47
# Época  96 - Loop 1005 de 1197: perda 2134.91 - MAE 2134.91
# Época  96 - Loop 1006 de 1197: perda 2239.16 - MAE 2239.16
# Época  96 - Loop 1007 de 1197: perda 2253.15 - MAE 2253.15
# Época  96 - Loop 1008 de 1197: perda 2237.76 - MAE 2237.76
# Época  96 - Loop 1009 de 1197: perda 2092.28 - MAE 2092.28
# Época  96 - Loop 1010 de 1197: perda 2310.60 - MAE 2310.60
# ...

# %% [markdown]
# ## Model Evaluation

# %%
regressor.eval()
# Out:
# Sequential(
#   (0): Linear(in_features=316, out_features=158, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=158, out_features=158, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=158, out_features=1, bias=True)
# )

# %%
previsoes = regressor.forward(previsores.to(device))

# %%
previsoes
# Out:
# tensor([[ 1055.9597],
#         [11548.1123],
#         [13998.4863],
#         ...,
#         [ 6131.9541],
#         [ 3761.1594],
#         [26551.2578]], device='cuda:0', grad_fn=<AddmmBackward0>)

# %%
preco_real
# Out:
# tensor([[  480.],
#         [18300.],
#         [ 9800.],
#         ...,
#         [ 9200.],
#         [ 3400.],
#         [28990.]])

# %%
preco_real.mean()
# Out:
# tensor(5916.8335)

# %%
previsoes.mean()
# Out:
# tensor(5773.6724, device='cuda:0', grad_fn=<MeanBackward0>)
